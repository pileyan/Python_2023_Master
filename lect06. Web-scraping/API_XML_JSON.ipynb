# %% [markdown]
# # Python для анализа данных
#
# ## Использование API. Работа с форматами XML и JSON
#
# *На основе лекции Ильи Щурова, НИУ ВШЭ*
# *Дополнения: Татьяна Рогович, НИУ ВШЭ*

# %% [markdown]
# # XML

# %% [markdown]
# До этого мы с вами собирали данные вручную, обращаясь к html страницам, размеченным для отображения в браузере. Но данные также можно собирать и через API -  — application program interface. Обычный интерфейс — это способ взаимодействия человека с программой, а API — одной программы с другой. Например, вашего скрипта на Python с удалённым веб-сервером.
#
# Для хранения веб-страниц, которые читают люди, используется язык HTML. Для хранения произвольных структурированных данных, которыми обмениваются между собой программы, используются другие языки — в частности, язык XML, похожий на HTML. Вернее было бы сказать, что XML это метаязык, то есть способ описания языков. В отличие от HTML, набор тегов в XML-документе может быть произвольным (и определяется разработчиком конкретного диалекта XML). Например, если бы мы хотели описать в виде XML некоторую студенческую группу, это могло бы выглядеть так:
#
# ```xml
# <group>
#     <number>134</number>
#     <student>
#         <firstname>Виталий</firstname>
#         <lastname>Иванов</lastname>
#     </student>
#     <student>
#         <firstname>Мария</firstname>
#         <lastname>Петрова</lastname>
#     </student>
# </group>
# ```

# %% [markdown]
# Для обработки XML-файлов можно использовать тот же пакет *Beautiful Soup*, который мы уже использовали для работы с HTML. Единственное различие — нужно указать дополнительный параметр `feautres="xml"` при вызове функции `BeautifulSoup` — чтобы он не искал в документе HTML-теги.

# %%
group = """<group>
<number>134</number>
<student>
<firstname>Виталий</firstname>
<lastname>Иванов</lastname>
</student>
<student>
<firstname>Мария</firstname>
<lastname>Петрова</lastname>
</student>
</group>"""

# %%
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in /Users/i.pile/anaconda3/lib/python3.8/site-packages (4.5.2)

# %%
from bs4 import BeautifulSoup

obj = BeautifulSoup(group, "lxml")
print(obj.prettify())
# Out:
# <html>
#  <body>
#   <group>
#    <number>
#     134
#    </number>
#    <student>
#     <firstname>
#      Виталий
#     </firstname>
#     <lastname>
#      Иванов
#     </lastname>
#    </student>
#    <student>
#     <firstname>
#      Мария
#     </firstname>
#     <lastname>
#      Петрова
#     </lastname>
#    </student>
#   </group>
#  </body>
# </html>

# %% [markdown]
# Номер группы можно найти, например, вот так - для каждого объекта через точку указываем его атрибут, в который надо спуститься.

# %%
obj.group.number.text # последний атрибут текст, точно также как делали в html
# Out:
# '134'

# %% [markdown]
# Но это работает только тогда, когда тэг уникальный. В других случаях, парсер всегда будет попадать в первый child-тэг, который он встретил по пути вниз.

# %%
obj.group.student.lastname.text # до Петровой так не добраться
# Out:
# 'Иванов'

# %% [markdown]
# Перечислить всех студентов можно с помощью цикла (похожая структура у нас была и в обработке html).

# %%
for student in obj.group.find_all('student'):
    print(student.lastname.text, student.firstname.text)
# Out:
# Иванов Виталий
# Петрова Мария

# %% [markdown]
# По сути, главное отличие xml от html, что работать вы будете не со стандартизированными структурами. Поэтому перед работой придется поиграть в детективов - запросить данные и внимательно изучить расположение узлов, чтобы понять, какие тэги вас интересуют.
#
# XML легко представить в виде дерева, где есть главный узел (parent) и его "дети".
#
# ![](https://www.py4e.com/images/xml-tree.svg)
# *Источник: Python for Everybody, C.Severance*

# %% [markdown]
# Кроме BS парсить xml можно и с помощью других библиотек. Например, ElementTree.

# %%
import xml.etree.ElementTree as ET

# %%
tree = ET.fromstring(group)
list(tree) # посмотрим, что внутри
# Out:
# [<Element 'number' at 0x7ff1a155d9f0>,
#  <Element 'student' at 0x7ff1a155d4f0>,
#  <Element 'student' at 0x7ff1a155d450>]

# %% [markdown]
# Cинтаксис очень похож на BS. Добрались до первой фамилии.

# %%
tree.find('student').find('lastname').text
# Out:
# 'Иванов'

# %%
for element in tree.findall('student'):
    print(element)
    print(element.find('lastname').text)
# Out:
# <Element 'student' at 0x7ff1a155d4f0>
# Иванов
# <Element 'student' at 0x7ff1a155d450>
# Петрова

# %% [markdown]
# Можно немного упростить код, включив дочерний тэг в findall.

# %%
for element in tree.findall('student/lastname'):
    print(element.text)
# Out:
# Иванов
# Петрова

# %% [markdown]
# # Задача
# По ссылке данные в формате xml.
# http://py4e-data.dr-chuck.net/comments_42.xml
#
# Посчитайте все комментарии в этом документе (поля count).

# %%
import requests
data = requests.get('http://py4e-data.dr-chuck.net/comments_42.xml').text

tree = ET.fromstring(data)

total = 0
for element in tree.findall('comments/comment/count'):
#     print(type(element.text)
    total += int(element.text)
    
print(total)
# Out:
# 2553

# %%
sum([int(element.text) for element in tree.findall('comments/comment/count')])
# Out:
# 2553

# %% [markdown]
# # Реальный пример: wiki API

# %% [markdown]
# Допустим, нам потребовалось получить список всех статей из некоторой категории в Википедии. Мы могли бы открыть эту категорию в браузере и дальше действовать теми методами, которые обсуждались выше. Однако, на наше счастье разработчики Википедии сделали удобное API. Чтобы научиться с ним работать, придётся познакомиться с [документацией](https://www.mediawiki.org/wiki/API:Main_page) (так будет с любым API), но это кажется сложным только в первый раз. Ну хорошо, в первые 10 раз. Или 20. Потом будет проще.
#
# Многие API будут требовать токена (например, ваш google логин-пароль для работы с гугл-документами), но мы сейчас работаем с открытым интерфейсом.
#
# Итак, приступим. Взаимодействие с сервером при помощи API происходит с помощью отправки специальным образом сформированных запросов и получения ответа в одном из машинночитаемых форматов. Нас будет интересовать формат XML, хотя бывают и другие (позже мы познакомимся с JSON). А вот такой запрос мы можем отправить:
#
# https://en.wikipedia.org/w/api.php?action=query&list=categorymembers&cmtitle=Category:Physics&cmsort=timestamp&cmdir=desc&format=xmlfm
#
# Строка `https://en.wikipedia.org/w/api.php` (до знака вопроса) — это *точка входа* в API. Всё, что идёт после знака вопроса — это, собственно, запрос. Он представляет собой что-то вроде словаря и состоит из пар «ключ=значение», разделяемых амперсандом `&`. Некоторые символы приходится кодировать специальным образом.
#
# Например, в адресе выше сказано, что мы хотим сделать запрос (`action=query`), перечислить элементы категории `list=categorymembers`, в качестве категории, которая нас интересует, указана `Category:Physics` (`cmtitle=Category:Physics`) и указаны некоторые другие параметры. Если кликнуть по этой ссылке, откроется примерно такая штука:
#
# ```xml
# <?xml version="1.0"?>
# <api batchcomplete="">
#   <continue cmcontinue="2015-05-30 19:37:50|1653925" continue="-||" />
#   <query>
#     <categorymembers>
#       <cm pageid="24293838" ns="0" title="Wigner rotation" />
#       <cm pageid="48583145" ns="0" title="Northwest Nuclear Consortium" />
#       <cm pageid="48407923" ns="0" title="Hume Feldman" />
#       <cm pageid="48249441" ns="0" title="Phase Stretch Transform" />
#       <cm pageid="47723069" ns="0" title="Epicatalysis" />
#       <cm pageid="2237966" ns="14" title="Category:Surface science" />
#       <cm pageid="2143601" ns="14" title="Category:Interaction" />
#       <cm pageid="10844347" ns="14" title="Category:Physical systems" />
#       <cm pageid="18726608" ns="14" title="Category:Physical quantities" />
#       <cm pageid="22688097" ns="0" title="Branches of physics" />
#     </categorymembers>
#   </query>
# </api>
# ```

# %% [markdown]
# Мы видим здесь разные теги, и видим, что нас интересуют теги `<cm>`, находящиеся внутри тега `<categorymembers>`.
#
# Давайте сделаем соответствующий запрос с помощью Python. Для этого нам понадобится уже знакомый модуль `requests`.

# %%
import requests
url = "https://en.wikipedia.org/w/api.php"
params = {
    'action':'query',
    'list':'categorymembers',
    'cmtitle': 'Category:Physics',
    'format': 'xml'
}

g = requests.get(url, params=params)

# %% [markdown]
# Как видно, список параметров мы передаем в виде обычного словаря. Посмотрим, что получилось.

# %%
g.text
# Out:
# '<?xml version="1.0"?><api batchcomplete=""><continue cmcontinue="subcat|403a4e504e030648385a4e3a2e4e050e4c32402a50323004403a4e504e011f01dcc1dc18|37358141" continue="-||" /><query><categorymembers><cm pageid="22939" ns="0" title="Physics" /><cm pageid="1653925" ns="100" title="Portal:Physics" /><cm pageid="23479" ns="0" title="Physicalism" /><cm pageid="70983414" ns="14" title="Category:Physics by country" /><cm pageid="49740128" ns="14" title="Category:Subfields of physics" /><cm pageid="694942" ns="14" title="Category:Physicists" /><cm pageid="5625591" ns="14" title="Category:Physics awards" /><cm pageid="36477012" ns="14" title="Category:Concepts in physics" /><cm pageid="71976587" ns="14" title="Category:Physics events" /><cm pageid="1310583" ns="14" title="Category:History of physics" /></categorymembers></query></api>'

# %%
# ?g.ok # возвращает ошибку, если сервер или клиент не отвечает
# Out:
# Type:        property
# String form: <property object at 0x00000223E404E408>
# Docstring:
# Returns True if :attr:`status_code` is less than 400.
#
# This attribute checks if the status code of the response is between
# 400 and 600 to see if there was a client error or a server error. If
# the status code, is between 200 and 400, this will return True. This
# is **not** a check to see if the response code is ``200 OK``.

# %% [markdown]
# Всё хорошо. Теперь используем *Beautiful Soup* для обработки этого XML.

# %%
data = BeautifulSoup(g.text, features='lxml')

# %%
print(data.prettify())
# Out:
# <?xml version="1.0"?>
# <html>
#  <body>
#   <api batchcomplete="">
#    <continue cmcontinue="subcat|403a4e504e030648385a4e3a2e4e050e4c32402a50323004403a4e504e011f01dcc1dc18|37358141" continue="-||">
#    </continue>
#    <query>
#     <categorymembers>
#      <cm ns="0" pageid="22939" title="Physics">
#      </cm>
#      <cm ns="100" pageid="1653925" title="Portal:Physics">
#      </cm>
#      <cm ns="0" pageid="23479" title="Physicalism">
#      </cm>
#      <cm ns="14" pageid="70983414" title="Category:Physics by country">
#      </cm>
#      <cm ns="14" pageid="49740128" title="Category:Subfields of physics">
#      </cm>
#      <cm ns="14" pageid="694942" title="Category:Physicists">
#      </cm>
#      <cm ns="14" pageid="5625591" title="Category:Physics awards">
#      </cm>
#      <cm ns="14" pageid="36477012" title="Category:Concepts in physics">
#      </cm>
#      <cm ns="14" pageid="71976587" title="Category:Physics events">
#      </cm>
#      <cm ns="14" pageid="1310583" title="Category:History of physics">
#      </cm>
#     </categorymembers>
#    </query>
#   </api>
#  </body>
# </html>

# %% [markdown]
# Найдём все вхождения тега `<cm>` и выведем их атрибут `title`:

# %%
for cm in data.api.query.categorymembers("cm"):
    print(cm['title'])
# Out:
# Physics
# Portal:Physics
# Physicalism
# Category:Physics by country
# Category:Subfields of physics
# Category:Physicists
# Category:Physics awards
# Category:Concepts in physics
# Category:Physics events
# Category:History of physics

# %% [markdown]
# Можно было упростить поиск `<cm>`, не указывая «полный путь» к ним:

# %%
for cm in data("cm"):
    print(cm['title'])
# Out:
# Physics
# Portal:Physics
# Physicalism
# Category:Physics by country
# Category:Subfields of physics
# Category:Physicists
# Category:Physics awards
# Category:Concepts in physics
# Category:Physics events
# Category:History of physics

# %% [markdown]
# По умолчанию сервер вернул нам список из 10 элементов. Если мы хотим больше, нужно воспользоваться элементом `continue` — это своего рода гиперссылка на следующие 10 элементов.

# %%
data.find("continue")['cmcontinue']
# Out:
# 'subcat|403a4e504e030648385a4e3a2e4e050e4c32402a50323004403a4e504e011f01dcc1dc18|37358141'

# %% [markdown]
# Мне пришлось использовать метод `find()` вместо того, чтобы просто написать `data.continue`, потому что `continue` в Python имеет специальный смысл.
#
# Теперь добавим `cmcontinue` в наш запрос и выполним его ещё раз:

# %%
params['cmcontinue'] = data.api("continue")[0]['cmcontinue']

# %%
params
# Out:
# {'action': 'query',
#  'list': 'categorymembers',
#  'cmtitle': 'Category:Physics',
#  'format': 'xml',
#  'cmcontinue': 'subcat|403a4e504e030648385a4e3a2e4e050e4c32402a50323004403a4e504e011f01dcc1dc18|37358141'}

# %%
g = requests.get(url, params=params)
data = BeautifulSoup(g.text, features='xml')
for cm in data.api.query.categorymembers("cm"):
    print(cm['title'])
# Out:
# Category:Physics-related lists
# Category:Physics literature
# Category:Physical modeling
# Category:Physics organizations
# Category:Physical systems
# Category:Works about physics
# Category:Physics stubs

# %% [markdown]
# Мы получили следующие 10 элементов из категории. Продолжая таким образом, можно выкачать её даже целиком (правда, для этого потребуется много времени).
#
# Аналогичным образом реализована работа с разнообразными другими API, имеющимися на разных сайтах. Где-то API является полностью открытым (как в Википедии), где-то вам потребуется зарегистрироваться и получить application id и какой-нибудь ключ для доступа к API, где-то попросят даже заплатить (например, автоматический поиск в Google стоит что-то вроде 5 долларов за 100 запросов). Есть API, которые позволяют только читать информацию, а бывают и такие, которые позволяют её править. Например, можно написать скрипт, который будет автоматически сохранять какую-то информацию в Google Spreadsheets. Всякий раз при использовании API вам придётся изучить его документацию, но это в любом случае проще, чем обрабатывать HTML-код. Иногда удаётся упростить доступ к API, используя специальные библиотеки.

# %% [markdown]
# # JSON
#
# Другой популярный формат, в котором клиент может отдать вам данные - json. JSON расшифровывается как JavaScript Object Notation и изначально возник как подмножество языка JavaScript (пусть вас не вводит в заблуждение название, этот язык ничего не имеет общего с Java), используемое для описания объектов, но впоследствии стал использоваться и в других языках программирования, включая Python. Различные API могут поддерживать либо XML, либо JSON, либо и то, и другое, так что нам полезно научиться работать с обоими типами данных (например, wiki api могла бы выгрузить нам данные и в формате json при соответствующем запросе).

# %%
url = "https://en.wikipedia.org/w/api.php"
params = {
    'action':'query',
    'list':'categorymembers',
    'cmtitle': 'Category:Physics',
    'format': 'json' # поменяли формат на json
}

j = requests.get(url, params=params)
j.ok
# Out:
# True

# %%
j.text
# Out:
# '{"batchcomplete":"","continue":{"cmcontinue":"subcat|403a4e504e030648385a4e3a2e4e050e4c32402a50323004403a4e504e011f01dcc1dc18|37358141","continue":"-||"},"query":{"categorymembers":[{"pageid":22939,"ns":0,"title":"Physics"},{"pageid":1653925,"ns":100,"title":"Portal:Physics"},{"pageid":23479,"ns":0,"title":"Physicalism"},{"pageid":70983414,"ns":14,"title":"Category:Physics by country"},{"pageid":49740128,"ns":14,"title":"Category:Subfields of physics"},{"pageid":694942,"ns":14,"title":"Category:Physicists"},{"pageid":5625591,"ns":14,"title":"Category:Physics awards"},{"pageid":36477012,"ns":14,"title":"Category:Concepts in physics"},{"pageid":71976587,"ns":14,"title":"Category:Physics events"},{"pageid":1310583,"ns":14,"title":"Category:History of physics"}]}}'

# %% [markdown]
# Посмотрим, что достали. Уже сразу видно, что структура у данных совсем другая.
#
# JSON очень похож на описание объекта в Python и смысл квадратных и фигурных скобок такой же. Правда, есть и отличия: например, в Python одинарные и двойные кавычки ничем не отличаются, а в JSON можно использовать только двойные. Мы видим, что полученный нами JSON представляет собой словарь, значения которого — строки или числа, а также списки или словари, значения которых в свою очередь также могут быть строками, числами, списками, словарями и т.д. То есть получается такая довольно сложная структура данных.
#
# В данный момент тот факт, что перед нами сложная структура данных, видим только мы — с точки зрения Python, j.text это просто такая строка. Однако в модуле requests есть метод, позволяющий сразу выдать питоновский объект (словарь или список), если результат запроса возвращён в формате JSON. Так что нам не придётся использовать никакие дополнительные библиотеки.

# %%
j_data = j.json()

# %%
j_data # получили честный питоновский словарь
# Out:
# {'batchcomplete': '',
#  'continue': {'cmcontinue': 'subcat|403a4e504e030648385a4e3a2e4e050e4c32402a50323004403a4e504e011f01dcc1dc18|37358141',
#   'continue': '-||'},
#  'query': {'categorymembers': [{'pageid': 22939, 'ns': 0, 'title': 'Physics'},
#    {'pageid': 1653925, 'ns': 100, 'title': 'Portal:Physics'},
#    {'pageid': 23479, 'ns': 0, 'title': 'Physicalism'},
#    {'pageid': 70983414, 'ns': 14, 'title': 'Category:Physics by country'},
#    {'pageid': 49740128, 'ns': 14, 'title': 'Category:Subfields of physics'},
#    {'pageid': 694942, 'ns': 14, 'title': 'Category:Physicists'},
#    {'pageid': 5625591, 'ns': 14, 'title': 'Category:Physics awards'},
#    {'pageid': 36477012, 'ns': 14, 'title': 'Category:Concepts in physics'},
#    {'pageid': 71976587, 'ns': 14, 'title': 'Category:Physics events'},
#    {'pageid': 1310583, 'ns': 14, 'title': 'Category:History of physics'}]}}

# %% [markdown]
# Содержательная информация хранится по ключу 'query'. А уже внутри есть ключ 'categorymembers', значением которого является список всех категорий. Каждая категория отображается в виде словаря, записями которого являются разные параметры категории (например, 'title' соответствует названию, а pageid — внутреннему идентификатору в системе).

# %%
j_data['query']['categorymembers'] # привычный нам список
# Out:
# [{'pageid': 22939, 'ns': 0, 'title': 'Physics'},
#  {'pageid': 1653925, 'ns': 100, 'title': 'Portal:Physics'},
#  {'pageid': 23479, 'ns': 0, 'title': 'Physicalism'},
#  {'pageid': 70983414, 'ns': 14, 'title': 'Category:Physics by country'},
#  {'pageid': 49740128, 'ns': 14, 'title': 'Category:Subfields of physics'},
#  {'pageid': 694942, 'ns': 14, 'title': 'Category:Physicists'},
#  {'pageid': 5625591, 'ns': 14, 'title': 'Category:Physics awards'},
#  {'pageid': 36477012, 'ns': 14, 'title': 'Category:Concepts in physics'},
#  {'pageid': 71976587, 'ns': 14, 'title': 'Category:Physics events'},
#  {'pageid': 1310583, 'ns': 14, 'title': 'Category:History of physics'}]

# %%
for cm in j_data['query']['categorymembers']: # пройдемся по нему привычным нам циклом
    print(cm['title'])
# Out:
# Physics
# Portal:Physics
# Physicalism
# Category:Physics by country
# Category:Subfields of physics
# Category:Physicists
# Category:Physics awards
# Category:Concepts in physics
# Category:Physics events
# Category:History of physics

# %% [markdown]
# Преимущества JSON в том, что мы получаем готовый объект Python и нет необходимости использовать какие-то дополнительные библиотеки для того, чтобы с ним работать. Недостатком является то же самое: зачастую поиск информации в XML-файле может проводиться более эффективно, чем в JSON. Продемонстрируем это на уже рассмотренном примере. Чтобы получить список всех тегов <cm>, в которых хранилась информация об элементах категории в XML, мы использовали полный «путь»:
#
# ```python
# for cm in data.api.query.categorymembers("cm"):
#     print(cm['title'])
# ```
#
# Однако, это можно бы сделать (в данном случае) гораздо короче. Если посмотреть на XML, то можно заметить, что в нём нет других тегов <cm>, кроме тех, которые нам нужны. С другой стороны, Beautiful Soup ищет все теги с данным именем, а не только те, которые являются потомками первого уровня для данного тега. Таким образом, код выше можно было бы переписать более коротко:

# %%
for cm in data("cm"):
    print(cm['title'])
# Out:
# Category:Physics-related lists
# Category:Physics literature
# Category:Physics organizations
# Category:Physics stubs

# %% [markdown]
# Конечно data("cm") выглядит короче, чем q['query']['categorymembers']. В JSON мы не можем использовать подобные методы. Так что у обоих форматов есть свои плюсы и минусы.

# %% [markdown]
# ## JSON (парсинг VK)
#
# Как уже говорилось выше, не все API открытые. Так, чтобы достать информацию из vk вам придется сгенерировать токен с помощью вашего аккаунта (мы выложим отдельный блокнот как это сделать, для тех, кому будет интересно). API VK отдает данные в json. Структура тут будет посложнее, чем то, что мы уже видели, поэтому давайте еще потренируемся.

# %% [markdown]
# Теперь научимся еще и загружать JSON файл с диска. Для этого нам понадобится модуль json.

# %%
import json
with open('vk.json',  'r', encoding='Utf-8') as json_data:
    res_loaded = json.load(json_data) # считываем данные с помощью функции .load()

# %% [markdown]
# Здесь у нас выгрузка постов со стены группы ВШЭ.

# %%
res_loaded
# Out:
# {'count': 1542,
#  'items': [{'id': 32494,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1541422799,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': '',
#    'attachments': [{'type': 'link',
#      'link': {'url': 'http://family.hse.ru/event/view/2271',
#       'title': 'День карьеры факультета бизнеса и менеджмента',
#       'caption': 'family.hse.ru',
#       'description': '',
#       'photo': {'id': 456239093,
#        'album_id': -2,
#        'owner_id': 100,
#        'photo_75': 'https://pp.userapi.com/c850336/v850336548/628ea/TwPjzdADVZ4.jpg',
#        'photo_130': 'https://pp.userapi.com/c850336/v850336548/628eb/gMSUSljxiC8.jpg',
#        'photo_604': 'https://pp.userapi.com/c850336/v850336548/628ec/kIMEO_f_3JQ.jpg',
#        'width': 150,
#        'height': 80,
#        'text': '',
#        'date': 1541422799}}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 6, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 2, 'user_reposted': 0},
#    'views': {'count': 2832}},
#   {'id': 32493,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1541076555,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': 'На Шаболовке 7 ноября в 18:30 ауд 5215 состоится встреча с представителем оргкомитета симпозиума, Lars John. Авторы лучших эссе получат возможность участвовать в симпозиуме в Швейцарии, а автор cамого лучшего эссе получит значительный денежный приз. Приглашаем всех студентов магистратуры, студентов 4 курса и аспирантов принять участие в этой встрече. \n \nTo all grad/postgrad and 4th year undergraduate students: compete until 1 Feb 2019 and qualify as a Leader of Tomorrow for the #49sgs (8–10 May 2019) in Switzerland, all expenses paid. Create an impact and win CHF 20,000. Leaders who have attended in the past include Niall Ferguson, Jack Ma, Christine Lagarde, Paul Polman, Anders Fogh Rasmussen, Ratan Tata, Muhammad Yunus, and many more. Register now at www.symp.sg/apply',
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 2, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 1, 'user_reposted': 0},
#    'views': {'count': 3943}},
#   {'id': 32492,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1540743239,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': '',
#    'attachments': [{'type': 'link',
#      'link': {'url': 'https://logistics.hse.ru/news/226897419.html',
#       'title': 'Лучшие выпускники Школы логистики получили международные сертификаты',
#       'caption': 'logistics.hse.ru',
#       'description': 'Событие в Школе логистики',
#       'photo': {'id': 456239301,
#        'album_id': -2,
#        'owner_id': 100,
#        'photo_75': 'https://pp.userapi.com/c846417/v846417451/111745/gC-IAV8kVks.jpg',
#        'photo_130': 'https://pp.userapi.com/c846417/v846417451/111746/oKMb8a5d_88.jpg',
#        'photo_604': 'https://pp.userapi.com/c846417/v846417451/111747/QD0TSfXe9dI.jpg',
#        'width': 150,
#        'height': 100,
#        'text': '',
#        'date': 1540742411}}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 5, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 1, 'user_reposted': 0},
#    'views': {'count': 4724}},
#   {'id': 32491,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1540551399,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': '',
#    'attachments': [{'type': 'link',
#      'link': {'url': 'https://manconf.hse.ru/2018/',
#       'title': '11-я Ежегодная научная конференция «Бизнес. Исследования. Образование»',
#       'caption': 'manconf.hse.ru',
#       'description': '',
#       'photo': {'id': 456245722,
#        'album_id': -2,
#        'owner_id': 100,
#        'photo_75': 'https://pp.userapi.com/c851332/v851332228/2d686/0U0aJVKLKRk.jpg',
#        'photo_130': 'https://pp.userapi.com/c851332/v851332228/2d687/ztJjSj4XUYQ.jpg',
#        'photo_604': 'https://pp.userapi.com/c851332/v851332228/2d688/cyrCjBtG_hA.jpg',
#        'width': 150,
#        'height': 78,
#        'text': '',
#        'date': 1540421392}}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 7, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 1, 'user_reposted': 0},
#    'views': {'count': 4466}},
#   {'id': 32488,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1540302306,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': '',
#    'attachments': [{'type': 'link',
#      'link': {'url': 'https://bi.hse.ru/isman/news/226555635.html',
#       'title': 'Очередная Осенняя школа по бизнес-информатике в Перми',
#       'caption': 'bi.hse.ru',
#       'description': 'C 8 по 10 октября в НИУ ВШЭ – Пермь состоялась очередная Осенняя школа по бизнес-информатике, в организации и проведении которой ежегодно принимают активное участие преподаватели и выпускники кафедры управления ИС и цифровой инфраструктурой.',
#       'photo': {'id': 456239091,
#        'album_id': -2,
#        'owner_id': 100,
#        'photo_75': 'https://pp.userapi.com/c846120/v846120166/126d23/RLnvsMhoxPY.jpg',
#        'photo_130': 'https://pp.userapi.com/c846120/v846120166/126d24/LEp32EcX4a8.jpg',
#        'photo_604': 'https://pp.userapi.com/c846120/v846120166/126d25/-iIz6wGbWBU.jpg',
#        'width': 150,
#        'height': 100,
#        'text': '',
#        'date': 1540302306}}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 5, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 3, 'user_reposted': 0},
#    'views': {'count': 6605}},
#   {'id': 32486,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1539863523,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': '26-28 октября в Москве пройдет крупнейший в России международный хакатон Hack.Moscow \n \nНа 36 часов новая площадка 1С в Москве примет 450 участников из 47 стран. На протяжении Hack.Moscow участникам будут предложены 8 треков с заданиями по различным тематикам, образовательные лекции и воркшопы. \n \nХакатон – это событие для комьюнити разработчиков, насыщенное интеллектом, технологиями и атмосферой запуска проектов, где команды за короткий промежуток времени соревнуются в создании IT-продуктов. \n \nСобытие организовано крупнейшим комьюнити участников хакатонов Russian Hackers совместно с международной лигой MLH. Среди треков на хакатоне: AI, Big Data, Blockchain, CTF, Entertainment, Digitalization, E-commerce, Fintech. Партнеры мероприятия: .etc, IBM, Nvidia, Avast, Here, НИУ ВШЭ, Иннополис. \n \nЧто ждет участников: \n \n— кейсы от крупных компаний: 1C, МТС, Росбанк, Сибур, WorldQuant, Bankex, Cleverbots \n \n— атмосфера международного хакатона и команды со всего мира \n \n— призовой фонд и море стикеров и мерча \n \n— 32 GPU Nvidia Tesla v100 для любителей нейросетей от Reg.ru \n \n— менторы и серьезные спикеры \n \nРегистрация открыта до 22 октября. Приглашаются разработчики, дизайнеры, data scientists, продукты и проджекты. На хакатон можно зарегистрироваться как самостоятельно, так и командой. \n \nБольше информации на сайте',
#    'attachments': [{'type': 'link',
#      'link': {'url': 'http://Hack.Moscow',
#       'title': 'Hack.Moscow v2.0',
#       'caption': 'hack.moscow',
#       'description': 'International hackathon in Russia. October 26-28, Moscow. Powered by Russian Hackers.'}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 5, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 2, 'user_reposted': 0},
#    'views': {'count': 5869}},
#   {'id': 32485,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1539781575,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': '',
#    'copy_history': [{'id': 14051,
#      'owner_id': -11798319,
#      'from_id': -11798319,
#      'date': 1539752406,
#      'post_type': 'post',
#      'text': '⚽ Официально. Спортивный бренд PUMA продолжит поддерживать вышкинский футбол! \n \n🌟 Бутсы как у Антуана Гризманна, форма как у Краснодара, мерч с автографом Анри! Еще год назад мы могли только об этом мечать, а уже сейчас это реальность. Дальше больше! \n \n👕 PUMA активно поддерживает студенческий спорт и в рамках партнёрства продолжит помогать с технической стороны, обеспечивая наш футбол всем необходимым - лучшей экипировкой, мячами и большим количеством ценных призов, выиграть которые будет возможность у каждого участника лиги. Постепенно мы расскажем вам об этих и о других приятных историях для команд и игроков. Но уже сейчас можно сказать, что Футбол ВШЭ вышел на новый уровень вместе с PUMA! \n \n#hsefootball #NewLevels #PUMAfootball #puma',
#      'attachments': [{'type': 'photo',
#        'photo': {'id': 456244924,
#         'album_id': -7,
#         'owner_id': -11798319,
#         'user_id': 100,
#         'photo_75': 'https://pp.userapi.com/c846522/v846522442/105f26/zWfai6_4JE8.jpg',
#         'photo_130': 'https://pp.userapi.com/c846522/v846522442/105f27/98JXmQPE9BI.jpg',
#         'photo_604': 'https://pp.userapi.com/c846522/v846522442/105f28/74xRv1CnM-U.jpg',
#         'photo_807': 'https://pp.userapi.com/c846522/v846522442/105f29/VawugKuM-Ag.jpg',
#         'photo_1280': 'https://pp.userapi.com/c846522/v846522442/105f2a/fDap8dVfWFY.jpg',
#         'width': 960,
#         'height': 639,
#         'text': '',
#         'date': 1539712761,
#         'post_id': 14051,
#         'access_key': 'd79faf4d9620174c65'}}],
#      'post_source': {'type': 'vk'}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 11, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'views': {'count': 4772}},
#   {'id': 32484,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1539718883,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': '',
#    'copy_history': [{'id': 18891,
#      'owner_id': -278573,
#      'from_id': -278573,
#      'date': 1539196320,
#      'post_type': 'post',
#      'text': 'Как начать карьеру в маркетинге? Мастер-класс 18 октября от партнера агентства Paper Planes и преподавателя Сколково Ильи Балахнина \n \nКак начать карьеру в маркетинге? На что следует обратить внимание? Какие шаги стоит предпринять? \n18 октября на эти вопросы ответит Илья Балахнин - преподаватель Московской Школы Управления “Сколково”, предприниматель и управляющий партнер маркетингового агенства Paper Planes. В практике Агентства более 500 успешных кейсов, сотни довольных Клиентов, включая «М.Видео», BOSCH, Mars и LG, которым помогли стать эффективнее и успешнее. \n \nТакже в рамках мастер-класса "Что такое маркетинг и как стать в нем профессионалом" вы узнаете что такое: \n- Стратегия маркетинга \n- Маркетинговые исследования: анализ рынка \n- Marketing Mix \nСможете задать все интересующие вопросы и получить самые развернутые ответы! \n \n18 октября в 18:00, \nШаболовка 26, ауд. К9 \nРегистрация: http://family.hse.ru/event/view/2264/ \n \n#события@hse_career',
#      'attachments': [{'type': 'photo',
#        'photo': {'id': 456244016,
#         'album_id': -7,
#         'owner_id': -278573,
#         'user_id': 100,
#         'photo_75': 'https://pp.userapi.com/c845016/v845016392/109fbd/v_Mg2IYNCrs.jpg',
#         'photo_130': 'https://pp.userapi.com/c845016/v845016392/109fbe/NP8cPR_ctFw.jpg',
#         'photo_604': 'https://pp.userapi.com/c845016/v845016392/109fbf/SoHlb0uaOa8.jpg',
#         'photo_807': 'https://pp.userapi.com/c845016/v845016392/109fc0/2VlTkij6kOA.jpg',
#         'photo_1280': 'https://pp.userapi.com/c845016/v845016392/109fc1/xR1-ERXDvXg.jpg',
#         'photo_2560': 'https://pp.userapi.com/c845016/v845016392/109fc2/pq5gWQg37Es.jpg',
#         'width': 2000,
#         'height': 1250,
#         'text': '',
#         'date': 1539161185,
#         'post_id': 18891,
#         'access_key': '841c6b9ad1cda28163'}}],
#      'post_source': {'type': 'vk'}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 2, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'views': {'count': 4385}},
#   {'id': 32481,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1539088885,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': '',
#    'copy_history': [{'id': 2466,
#      'owner_id': -85377161,
#      'from_id': -85377161,
#      'date': 1538581500,
#      'post_type': 'post',
#      'text': 'Друзья! \nХотите узнать как попасть на стажировку в международную IT- компанию и начать работу над глобальными проектами? \nПриходите 19 октября (пятница) в 18:30 на #TechTalk "Acronis Projects & Pizza" на ФКН НИУ ВШЭ, ауд. 317. \n\nВ программе встречи: \n• презентация программ стажировок в международной ИТ- компании; \n• возможность пообщаться «за кусочком пиццы» с ведущими разработчиками и в числе первых узнать о перспективных задачах для студентов; \n• презентации руководителей команд разработки Acronis: \n- Технологии Acronis в «Formula - 1», «Formula E» и футболе; \n- Технологии машинного обучения в продукте Acronis Total Protection; \n- Архитектура ПО Acronis: большие горизонты; \n\nО текущих проектах и работе своих команд расскажут: \nАндрей Кулага, директор по разработке в Acronis Systems Management and Monitoring Team. \nАнна Мелехова, архитектор ПО в Acronis Team. \n\nПосле встречи вас ждёт лотерея с брендированными призами Acronis, неформальное общение со спикерами и тестовые собеседования. \n\nДля участия необходимо пройти регистрацию: http://go.acronis.com/HSE19oct \n\n18:00 – 18:30 - welcome, пицца и напитки \n18:30 – 19:30 - Acronis Tech Talk \n19:30 – 20:00 - неформальное общение, розыгрыши фирменных призов и тестовые собеседования \nАдрес: Кочновский пр-д, 3 \nЖдём вас!',
#      'attachments': [{'type': 'photo',
#        'photo': {'id': 456241427,
#         'album_id': -7,
#         'owner_id': -85377161,
#         'user_id': 100,
#         'photo_75': 'https://pp.userapi.com/c845323/v845323495/104739/FdoD5PR3duE.jpg',
#         'photo_130': 'https://pp.userapi.com/c845323/v845323495/10473a/0Pai7BrRXEA.jpg',
#         'photo_604': 'https://pp.userapi.com/c845323/v845323495/10473b/03kVA3bd7ys.jpg',
#         'photo_807': 'https://pp.userapi.com/c845323/v845323495/10473c/ZGBo6Mkmqo0.jpg',
#         'photo_1280': 'https://pp.userapi.com/c845323/v845323495/10473d/uKP64Os72wk.jpg',
#         'width': 1200,
#         'height': 628,
#         'text': '',
#         'date': 1538581135,
#         'access_key': '19cd7ab0c2e3f3637a'}},
#       {'type': 'link',
#        'link': {'url': 'http://go.acronis.com/HSE19oct',
#         'title': 'Tech Talk "Acronis Projects & Pizza", 19 октября, 18:30, ФКН НИУ ВШЭ, ауд. 317',
#         'description': '',
#         'target': 'internal',
#         'photo': {'id': 456241179,
#          'album_id': -2,
#          'owner_id': 100,
#          'photo_75': 'https://pp.userapi.com/c850736/v850736038/17995/Q7FCRiDdadE.jpg',
#          'photo_130': 'https://pp.userapi.com/c850736/v850736038/17996/q634VXgWZVQ.jpg',
#          'photo_604': 'https://pp.userapi.com/c850736/v850736038/17997/uaSjY2TeVNY.jpg',
#          'width': 150,
#          'height': 32,
#          'text': '',
#          'date': 1538581135}}}],
#      'post_source': {'type': 'vk'}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 4, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'views': {'count': 5502}},
#   {'id': 32480,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1539088745,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': 'Будущим магистрам! Новая программа Факультета бизнеса и менеджмента "HR-аналитика". Прием на программу начинается в 2019 году по конкурсу портфолио. https://management.hse.ru/news/225469321.html?_r=206801539081229.7121&__t=4005952&__r=OK',
#    'attachments': [{'type': 'link',
#      'link': {'url': 'https://mail2.hse.ru/owa/redir.aspx?C=mWzc6MT8RaGrr3ehBqWGnuA5hhVBkW5i8spBAJDB62436hic4y3WCA..&URL=https%3a%2f%2fmanagement.hse.ru%2fnews%2f225469321.html%3f_r%3d206801539081229.7121%26__t%3d4005952%26__r%3dOK',
#       'title': 'Outlook Web App',
#       'caption': 'mail2.hse.ru',
#       'description': ''}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 3, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 1, 'user_reposted': 0},
#    'views': {'count': 5535}},
#   {'id': 32478,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1539016393,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': 'Будущим магистрам! Новая программа факультета бизнеса и менеджмента (реализует Школа логистики) https://logistics.hse.ru/news/225353561.html',
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 2, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 1, 'user_reposted': 0},
#    'views': {'count': 6337}},
#   {'id': 32476,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1538752645,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': 'До окончания регистрации в Осеннюю школу бизнес-проектов осталось 5 дней! \nРегистрация школьников 9-11 классов на Осеннюю школу бизнес-проектов (учебный центр "Вороново"). Школу проводит Факультет бизнеса и менеджмента НИУ ВШЭ совместно с Дирекцией по профориентации и по работе с талантливой молодежью. Регистрация https://shkolnikam.hse.ru/projectsc',
#    'attachments': [{'type': 'link',
#      'link': {'url': 'https://shkolnikam.hse.ru/projectsc',
#       'title': 'Осенняя проектная школа для школьников',
#       'caption': 'shkolnikam.hse.ru',
#       'description': '',
#       'photo': {'id': 456240017,
#        'album_id': -2,
#        'owner_id': 100,
#        'photo_75': 'https://pp.userapi.com/c845524/v845524545/106615/3EHrxwQRcRM.jpg',
#        'photo_130': 'https://pp.userapi.com/c845524/v845524545/106616/mK1Mf7-sAgs.jpg',
#        'photo_604': 'https://pp.userapi.com/c845524/v845524545/106617/yOUB3ALi36s.jpg',
#        'width': 150,
#        'height': 78,
#        'text': '',
#        'date': 1538590292}}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 7, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'views': {'count': 6038}},
#   {'id': 32475,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1538640660,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': '',
#    'copy_history': [{'id': 64,
#      'owner_id': -154645194,
#      'from_id': -154645194,
#      'date': 1538599418,
#      'post_type': 'post',
#      'text': 'Леонид Богуславский одним из первых инвестировал в Яндекс, OZON.ru, ivi.ru, Biglion, HeadHunter, 2GIS и помог сделать российский интернет таким, какой он есть сейчас. \n \nВ понедельник, 8 октября, в 17:15 Леонид приедет в наш университет для общения со студентами в формате беседы. \n \nДоктор технических наук Леонид Богуславский в 1990-ом году стал дистрибьютором Oracle в СССР, в 1996 году продал свою компанию и стал старшим партнёром Price Waterhouse (PwC), понимая перспективы интернета, в 2001 году ушёл из PwC и одним из первых инвестировал в Яндекс и Озон. В данный момент 5 компаний в США, Европе и Росси, в которые он инвестировал на ранней стадии, стоят миллиарды долларов каждая. Инвестиционные компании ru-Net и RTP Леонида Богуславского сегодня является инвестором более 40 компаний из Америки, Европы, России и Азии. В 2017 году по предложению Германа Грефа Леонид Богуславский вошёл в Наблюдательный совет "Сбербанка". \n \nНа встрече с Леонидом мы обсудим, как сделать миллиардную компанию на весь Мир, как принимать инвестиционные решения и чем руководствоваться в жизни, чтобы побеждать. Кроме того, в процессе мероприятия каждый сможет задавать свои собственные вопросы. \n \nПриглашаем на мероприятие студентов всех московских университетов! \n \nГде: корпус НИУ ВШЭ на ул. Кирпичной, 33 (м. Семеновская). \nКогда: 8 октября (понедельник) \nВо сколько: 17:15 \n \nВход строго по регистрации. \nСсылка для регистрации: https://hse-business-org.timepad.ru/event/825989/ \n \nСделай репост этой записи и получи шанс выиграть любимую книгу Леонида Богуславского: Крис Маккормак «Я здесь чтобы победить!», с его автографом! \n \nПодпишись на наш паблик, чтобы не пропустить наши дальнейшие мероприятия!',
#      'attachments': [{'type': 'photo',
#        'photo': {'id': 456239054,
#         'album_id': -7,
#         'owner_id': -154645194,
#         'user_id': 100,
#         'photo_75': 'https://pp.userapi.com/c850020/v850020122/8662e/3598dtDIV_s.jpg',
#         'photo_130': 'https://pp.userapi.com/c850020/v850020122/8662f/AnhdOakjDAo.jpg',
#         'photo_604': 'https://pp.userapi.com/c850020/v850020122/86630/UjQTGCCYg5w.jpg',
#         'photo_807': 'https://pp.userapi.com/c850020/v850020122/86631/4G93kcoCrFk.jpg',
#         'photo_1280': 'https://pp.userapi.com/c850020/v850020122/86632/tDjC0jXAoY4.jpg',
#         'width': 1024,
#         'height': 768,
#         'text': '',
#         'date': 1538599418,
#         'access_key': 'a85ba7f76bdb197c4e'}},
#       {'type': 'link',
#        'link': {'url': 'https://hse-business-org.timepad.ru/event/825989/',
#         'title': 'Встреча с Леонидом Богуславским в НИУ ВШЭ / События на TimePad.ru',
#         'description': '',
#         'target': 'internal'}}],
#      'post_source': {'type': 'vk'}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 12, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 5, 'user_reposted': 0},
#    'views': {'count': 4691}},
#   {'id': 32474,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1538513448,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': 'Продолжается регистрация школьников 9-11 классов на Осеннюю школу бизнес-проектов (учебный центр "Вороново"). Школу проводит Факультет бизнеса и менеджмента НИУ ВШЭ совместно с Дирекцией по профориентации и по работе с талантливой молодежью. Регистрация https://shkolnikam.hse.ru/projectsc',
#    'attachments': [{'type': 'link',
#      'link': {'url': 'https://shkolnikam.hse.ru/projectsc',
#       'title': 'Осенняя проектная школа для школьников',
#       'caption': 'shkolnikam.hse.ru',
#       'description': '',
#       'photo': {'id': 456239090,
#        'album_id': -2,
#        'owner_id': 100,
#        'photo_75': 'https://pp.userapi.com/c850436/v850436833/15c36/kIIBQZOEe2U.jpg',
#        'photo_130': 'https://pp.userapi.com/c850436/v850436833/15c37/jIOePX01Apg.jpg',
#        'photo_604': 'https://pp.userapi.com/c850436/v850436833/15c38/XniE7DSbaQY.jpg',
#        'width': 150,
#        'height': 84,
#        'text': '',
#        'date': 1538513448}}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 9, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'views': {'count': 5629}},
#   {'id': 32472,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1538477565,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': 'Для абитуриентов Школа логистики факультета бизнеса и менеджмента готовит цикл семинаров в декабре. Приглашают всех желающих https://logistics.hse.ru/announcements/224770564.html',
#    'attachments': [{'type': 'link',
#      'link': {'url': 'https://logistics.hse.ru/announcements/224770564.html',
#       'title': 'Цикл открытых семинаров по подготовке к олимпиаде по логистике и управлению цепями поставок',
#       'caption': 'logistics.hse.ru',
#       'description': 'Информация о цикле открытых семинаров по подготовке к олимпиаде по логистике и управлению цепями поставок',
#       'photo': {'id': 456239089,
#        'album_id': -2,
#        'owner_id': 100,
#        'photo_75': 'https://pp.userapi.com/c846221/v846221928/fdd18/xZDMLluYUHE.jpg',
#        'photo_130': 'https://pp.userapi.com/c846221/v846221928/fdd19/SKtyOG13k0U.jpg',
#        'photo_604': 'https://pp.userapi.com/c846221/v846221928/fdd1a/BH2-Syvtvqg.jpg',
#        'width': 150,
#        'height': 84,
#        'text': '',
#        'date': 1538477565}}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 2, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 6, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 1, 'user_reposted': 0},
#    'views': {'count': 5392}},
#   {'id': 32471,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1538044277,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': '',
#    'copy_history': [{'id': 2670,
#      'owner_id': -77947518,
#      'from_id': -77947518,
#      'date': 1537292460,
#      'post_type': 'post',
#      'text': '#BAINevent #joinBAIN #НИУВШЭ #кейс\n\nМы знаем, что студентов ВШЭ кейсом не удивишь. А как насчет обсуждения ваших решений вместе с младшим партнером Bain Олегом Гейлером и менеджером, а также выпускником НИУ ВШЭ Александром Болдыревым? 2 октября они приедут на Шаболовку, 26. Вы сможете пообщаться со спикерами в неформальной обстановке и на реальном примере понять, в чем состоит работа консультанта. Всем, кто хочет поучаствовать в решении кейса, необходимо зарегистрироваться: https://clck.ru/EPBF8 \n\nВстречаемся в 18:30 в корпусе Вышки на Шаболовке, 26.',
#      'attachments': [{'type': 'photo',
#        'photo': {'id': 456240297,
#         'album_id': -7,
#         'owner_id': -77947518,
#         'user_id': 100,
#         'photo_75': 'https://pp.userapi.com/c849328/v849328632/82e4f/sKZZdU7u1SE.jpg',
#         'photo_130': 'https://pp.userapi.com/c849328/v849328632/82e50/E5PKvUJuwZM.jpg',
#         'photo_604': 'https://pp.userapi.com/c849328/v849328632/82e51/QLeLSb3PThs.jpg',
#         'photo_807': 'https://pp.userapi.com/c849328/v849328632/82e52/VXtLSsTbBRo.jpg',
#         'photo_1280': 'https://pp.userapi.com/c849328/v849328632/82e53/w41HaTU-M7E.jpg',
#         'photo_2560': 'https://pp.userapi.com/c849328/v849328632/82e54/HLE_LGW35mo.jpg',
#         'width': 2084,
#         'height': 1170,
#         'text': '',
#         'date': 1537285404,
#         'access_key': '8fe594a0d6d6372fb1'}},
#       {'type': 'link',
#        'link': {'url': 'https://careers.bain.com/recruits/EventDetail?folderId=15057',
#         'title': 'Case Seminar at HSE 18:30 October 2nd 2018 Moscow',
#         'description': '',
#         'target': 'internal'}}],
#      'post_source': {'type': 'vk'}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 8, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'views': {'count': 5443}},
#   {'id': 32470,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1537815734,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': 'Приглашаем 29 октября - 4 ноября школьников 9-11 классов на Осеннюю школу бизнес-проектов в учебный центр "Вороново". Школу проводит Факультет бизнеса и менеджмента НИУ ВШЭ совместно с Дирекцией по профориентации и по работе с талантливой молодежью. Регистрация https://shkolnikam.hse.ru/projectsc',
#    'attachments': [{'type': 'link',
#      'link': {'url': 'https://shkolnikam.hse.ru/projectsc',
#       'title': 'Осенняя проектная школа для школьников',
#       'caption': 'shkolnikam.hse.ru',
#       'description': ''}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 14, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 7, 'user_reposted': 0},
#    'views': {'count': 7800}},
#   {'id': 32469,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1537779781,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': 'Привет! Ты начинающий дизайнер, программист или, может быть, хочешь сделать свой стартап? Тогда приглашаем тебя на презентацию Russian Hackers, где мы расскажем о хакатонах — месте, в котором ты сможешь развить все нужные навыки, найти знакомых для реализации своих идей и просто весело, но с пользой провести время. \n \nЖдем тебя в Таблице (Новослободская ул., 16) 26 сентября. Не забудь зарегистрироваться! \n\nСсылка: https://russian-hacker.timepad.ru/event/800309/',
#    'attachments': [{'type': 'photo',
#      'photo': {'id': 456239898,
#       'album_id': -7,
#       'owner_id': -132,
#       'user_id': 100,
#       'photo_75': 'https://pp.userapi.com/c852320/v852320098/ed6a/aIWw2xO0lcE.jpg',
#       'photo_130': 'https://pp.userapi.com/c852320/v852320098/ed6b/lTkbFsvhW-0.jpg',
#       'photo_604': 'https://pp.userapi.com/c852320/v852320098/ed6c/Zv0cWsMbPmY.jpg',
#       'photo_807': 'https://pp.userapi.com/c852320/v852320098/ed6d/F5ki1icO_ww.jpg',
#       'width': 796,
#       'height': 349,
#       'text': '',
#       'date': 1537779781,
#       'post_id': 32469,
#       'access_key': '9c56edab744fd56bf7'}},
#     {'type': 'link',
#      'link': {'url': 'https://russian-hacker.timepad.ru/event/800309/',
#       'title': 'Презентация Russian Hackers / События на TimePad.ru',
#       'description': '26 сентября в здании коворкинге Таблица пройдет презентация студенческой организации и крупнейшего рускоязычного комьюнити участников хакатонов Russian Hackers.',
#       'target': 'internal',
#       'photo': {'id': 456266777,
#        'album_id': -2,
#        'owner_id': 100,
#        'photo_75': 'https://pp.userapi.com/c846218/v846218561/f90d6/IAmAupm3nyw.jpg',
#        'photo_130': 'https://pp.userapi.com/c846218/v846218561/f90d7/KbuhDzX5euE.jpg',
#        'photo_604': 'https://pp.userapi.com/c846218/v846218561/f90d8/1v14FGSmcE4.jpg',
#        'width': 150,
#        'height': 43,
#        'text': '',
#        'date': 1537779781}}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 14, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 2, 'user_reposted': 0},
#    'views': {'count': 6640}},
#   {'id': 32467,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1537450286,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': '',
#    'copy_history': [{'id': 18697,
#      'owner_id': -278573,
#      'from_id': -278573,
#      'date': 1536949500,
#      'post_type': 'post',
#      'text': 'Встреча 25 сентября с генеральным директором «ВТБ Страхование жизни» Максимом Пушкаревым «Надеясь на лучшее: почему страхование жизни стремительно растет». \n \nГенеральный директор «ВТБ Страхование жизни», выпускник факультета бизнеса и менеджмента Максим Пушкарев выступит в Вышке и расскажет о бизнесе, клиентах, риск-менеджменте и, конечно же, имеющихся в компании карьерных возможностях – вакансиях и стажировках. \n \nЖдем студентов любых образовательных программ и любых курсов: страхование это и про людей и их ценности, и про математику, и, конечно, про бизнес и продажи. \nЖдем выпускников: Максим расскажет про риск-менеджмент, про развитие страховых продуктов, а также про финансовую сторону сегмента страхования жизни. \nЖдем всех, кому интересен опыт работы в страховании первого лица одной из крупнейших страховых компаний России: с чем приходилось сталкиваться в работе; чем отличается страхование изнутри от того, что мы видим, как потребители; какие предметы учить, чтобы пойти работать в страхование и так далее. \n \nДата: 25 сентября \nВремя: 19:30 \nАдрес: Мясницкая, 20, ауд. 101 \nРегистрация: hsealumni.timepad.ru/event/809668',
#      'attachments': [{'type': 'photo',
#        'photo': {'id': 456243688,
#         'album_id': -7,
#         'owner_id': -278573,
#         'user_id': 100,
#         'photo_75': 'https://pp.userapi.com/c845522/v845522292/f12f8/TGIgk7jDJvQ.jpg',
#         'photo_130': 'https://pp.userapi.com/c845522/v845522292/f12f9/YHj3RxVI58w.jpg',
#         'photo_604': 'https://pp.userapi.com/c845522/v845522292/f12fa/Sdpd3nXpUw0.jpg',
#         'photo_807': 'https://pp.userapi.com/c845522/v845522292/f12fb/zReqdSeBN_U.jpg',
#         'photo_1280': 'https://pp.userapi.com/c845522/v845522292/f12fc/l-0uUjfzHKM.jpg',
#         'width': 960,
#         'height': 720,
#         'text': '',
#         'date': 1536926051,
#         'post_id': 18697,
#         'access_key': '899fc8a4ddecb05b77'}}],
#      'post_source': {'type': 'vk'}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 1, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 4, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'views': {'count': 5099}},
#   {'id': 32465,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1537357519,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': '',
#    'copy_history': [{'id': 1790,
#      'owner_id': -89765286,
#      'from_id': -89765286,
#      'date': 1537357512,
#      'post_type': 'post',
#      'text': 'Приглашаем абитуриентов и их родителей на День открытых дверей образовательных программ по логистике и управлению цепями поставок. В программе презентация бакалаврской программы "Логистика и управление цепями поставок" и магистерских программ "Стратегическое управление логистикой" и "Инновационные технологии управления цепями поставок". \n\nВыступление руководителя Школы логистики д.э.н., профессора В.В. Дыбской, а также ведущих преподавателей Школы логистики будет посвящено следующим вопросам: \n\n- Логистика, как наука и практический инструмент оптимизации ресурсов предприятия. \n- Вступительные испытания. Бюджетные места и места с оплатой стоимости обучения. \n- Перспективы трудоустройства выпускников в различных сферах бизнеса. \n- Международные программы отделения логистики и научно-исследовательская деятельность студентов. \n- Обзор изучаемых дисциплин. \n\nДень открытых дверей состоится 23 октября 2018 в 18:30 по адресу Москва, Большой Трехсвятительский переулок, 3, ауд. 200. \n\nПодробнее: https://logistics.hse.ru/announcements/223324052.html',
#      'attachments': [{'type': 'link',
#        'link': {'url': 'https://logistics.hse.ru/announcements/223324052.html',
#         'title': 'День открытых дверей образовательных программ по логистике и управлению цепями поставок',
#         'caption': 'logistics.hse.ru',
#         'description': 'Анонс дня открытых дверей образовательных программ по логистике и управлению цепями поставок в НИУ ВШЭ',
#         'photo': {'id': 456239849,
#          'album_id': -2,
#          'owner_id': 100,
#          'photo_75': 'https://pp.userapi.com/c852136/v852136727/f38/a2RNRVjnL5o.jpg',
#          'photo_130': 'https://pp.userapi.com/c852136/v852136727/f39/I2VeKqlGHaY.jpg',
#          'photo_604': 'https://pp.userapi.com/c852136/v852136727/f3a/S7k1UN4cf8A.jpg',
#          'width': 150,
#          'height': 78,
#          'text': '',
#          'date': 1536766070}}}],
#      'post_source': {'type': 'vk'}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 3, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 1, 'user_reposted': 0},
#    'views': {'count': 5617}},
#   {'id': 32464,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1537356318,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': '',
#    'copy_history': [{'id': 1789,
#      'owner_id': -89765286,
#      'from_id': -89765286,
#      'date': 1537356311,
#      'post_type': 'post',
#      'text': 'Факультет бизнеса и менеджмента НИУ ВШЭ и Дирекция по профессиональной ориентации и работе с одаренными учащимися приглашает старшеклассников, желающих получить навыки проектной деятельности, в Осеннюю школу бизнес-проектов. \n \nВ работе ОШБП-2018 будут участвовать студенты, выпускники, преподаватели Факультета бизнеса и менеджмента, а также представители бизнеса. \n\nПрограмма Школы бизнес-проектов разработана командой преподавателей и студентов факультета бизнеса и менеджмента НИУ ВШЭ, одним из лидеров в области управления бизнесом и бизнес-информатики. \n \nОсобенность Школы бизнес-проектов в том, что ее участники в группах по 5 человек под руководством опытных менторов (студентов старших курсов бакалавриата) сделают первые шаги в реализации собственного бизнес-проекта: от поиска идеи до реализации проекта. Бизнес-проекты предстоит защитить перед экспертной комиссией во главе с деканом факультета Н.Б.Филиновым. Авторы лучших проектов получат дипломы и призы спонсоров и партнеров факультета бизнеса и менеджмента НИУ ВШЭ, все участники - сувениры и сертификаты участника. \n\nПодробнее: https://shkolnikam.hse.ru/projectsc',
#      'attachments': [{'type': 'link',
#        'link': {'url': 'https://shkolnikam.hse.ru/projectsc',
#         'title': 'Осенняя проектная школа для школьников',
#         'caption': 'shkolnikam.hse.ru',
#         'description': '',
#         'photo': {'id': 456239849,
#          'album_id': -2,
#          'owner_id': 100,
#          'photo_75': 'https://pp.userapi.com/c852136/v852136727/f38/a2RNRVjnL5o.jpg',
#          'photo_130': 'https://pp.userapi.com/c852136/v852136727/f39/I2VeKqlGHaY.jpg',
#          'photo_604': 'https://pp.userapi.com/c852136/v852136727/f3a/S7k1UN4cf8A.jpg',
#          'width': 150,
#          'height': 78,
#          'text': '',
#          'date': 1536766070}}}],
#      'post_source': {'type': 'vk'}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 1, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'views': {'count': 4930}},
#   {'id': 32462,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1537168381,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': 'Иванова Валерия Станиславовна, документы найдены, контакт https://m.vk.com/smotra.drift',
#    'attachments': [{'type': 'link',
#      'link': {'url': 'https://m.vk.com/smotra.drift',
#       'title': '',
#       'caption': 'm.vk.com',
#       'description': ''}}],
#    'post_source': {'type': 'mvk'},
#    'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 3, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'views': {'count': 5698}},
#   {'id': 32459,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1536952253,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': 'Факультет бизнеса и менеджмента совместно с Дирекцией по профориентации и работе с талантливой молодежью НИУ ВШЭ открывает регистрация старшеклассников для участия в Осенней Школе Бизнес-Проектов (ОШБП-2018). Школа пройдет с 29.10. по 4.11 в учебном центре "Вороново". https://shkolnikam.hse.ru/projectsc',
#    'attachments': [{'type': 'doc',
#      'doc': {'id': 475356235,
#       'owner_id': 6998,
#       'title': 'Programma_OShBP_2018.docx',
#       'size': 24614,
#       'ext': 'docx',
#       'url': 'https://vk.com/doc6998_475356235?hash=1fcc304a2c1e13b13b&dl=GE3DOOJUGU3TA:1541538437:55530754b9fc1abc77&api=1&no_preview=1',
#       'date': 1536947478,
#       'type': 1,
#       'access_key': 'e211dfdf5b4edf0707'}},
#     {'type': 'link',
#      'link': {'url': 'https://shkolnikam.hse.ru/projectsc',
#       'title': 'Осенняя проектная школа для школьников',
#       'caption': 'shkolnikam.hse.ru',
#       'description': '',
#       'photo': {'id': 456239849,
#        'album_id': -2,
#        'owner_id': 100,
#        'photo_75': 'https://pp.userapi.com/c852136/v852136727/f38/a2RNRVjnL5o.jpg',
#        'photo_130': 'https://pp.userapi.com/c852136/v852136727/f39/I2VeKqlGHaY.jpg',
#        'photo_604': 'https://pp.userapi.com/c852136/v852136727/f3a/S7k1UN4cf8A.jpg',
#        'width': 150,
#        'height': 78,
#        'text': '',
#        'date': 1536766070}}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 2, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 10, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 2, 'user_reposted': 0},
#    'views': {'count': 7707}},
#   {'id': 32458,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1536776359,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': '',
#    'copy_history': [{'id': 1770,
#      'owner_id': -89765286,
#      'from_id': -89765286,
#      'date': 1536776353,
#      'post_type': 'post',
#      'text': 'Ты уже был на новой площадке Nike BOX MSK? \nЕсли нет - самое время это исправить. \n \nДень Вышки - отличный повод уже завтра посетить совместный воркшоп Факультета бизнеса и менеджмента х Nike BOX MSK! ⠀ \n⠀⠀⠀ \n📍ГДЕ? - Nike BOX MSK (Парк Горького, Крымский Вал, 9)⠀ ⠀ ⠀ ⠀ \n⠀ ⠀ ⠀ ⠀ ⠀ \n🕓 КОГДА? - С 16:00 до 17:30 \n \n❓ЧТО БУДЕТ? \n \n- Разбор двух лучших реализованных проектов ОП “Маркетинг и рыночная аналитика” \n- История Nike BOX MSK от авторов проекта, а также возможность принять участие в дальнейшем развитии Nike BOX MSK, поделившись своими креативными идеями. \n \nЛучшие команды получат ценные призы от компании и университета! \n \nJUST DO IT. \n \nPS. Приходите вовремя, количество мест ограничено.\n\nhttps://bm.hse.ru/announcements/223486548.html',
#      'attachments': [{'type': 'photo',
#        'photo': {'id': 456239226,
#         'album_id': -7,
#         'owner_id': -89765286,
#         'user_id': 100,
#         'photo_75': 'https://pp.userapi.com/c849120/v849120295/6deb0/OsatSaC-NdY.jpg',
#         'photo_130': 'https://pp.userapi.com/c849120/v849120295/6deb1/1jeVnk4s4t0.jpg',
#         'photo_604': 'https://pp.userapi.com/c849120/v849120295/6deb2/88_xLS6iXzM.jpg',
#         'photo_807': 'https://pp.userapi.com/c849120/v849120295/6deb3/P_7L-fNcUFc.jpg',
#         'photo_1280': 'https://pp.userapi.com/c849120/v849120295/6deb4/I9G_S3Hkw0M.jpg',
#         'width': 960,
#         'height': 674,
#         'text': '',
#         'date': 1536776353,
#         'post_id': 1770,
#         'access_key': 'd61f9f0c2a6be121d8'}},
#       {'type': 'link',
#        'link': {'url': 'https://bm.hse.ru/announcements/223486548.html',
#         'title': 'Воркшоп Nike BOX MSK на Дне Вышки',
#         'description': 'Факультет бизнеса и менеджмента и компания Nike приглашает школьников и студентов в Nike Box MSK.',
#         'target': 'internal',
#         'photo': {'id': 456239849,
#          'album_id': -2,
#          'owner_id': 100,
#          'photo_75': 'https://pp.userapi.com/c852136/v852136727/f38/a2RNRVjnL5o.jpg',
#          'photo_130': 'https://pp.userapi.com/c852136/v852136727/f39/I2VeKqlGHaY.jpg',
#          'photo_604': 'https://pp.userapi.com/c852136/v852136727/f3a/S7k1UN4cf8A.jpg',
#          'width': 150,
#          'height': 78,
#          'text': '',
#          'date': 1536766070}}}],
#      'post_source': {'type': 'vk'}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 1, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 13, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 3, 'user_reposted': 0},
#    'views': {'count': 6437}},
#   {'id': 32457,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1536747843,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': '',
#    'copy_history': [{'id': 26,
#      'owner_id': -161949560,
#      'from_id': -161949560,
#      'date': 1536747797,
#      'post_type': 'post',
#      'text': 'Всем привет! \n \nНаступил новый учебный год, а это значит, что в вузе появилось много новых людей, которые, скорее всего, заинтересованы в информационной безопасности. В связи с этим, мы запускаем второй сезон лекций по информационной безопасности от команды PwC, FBK Cybersecurity и Информзащиты. На этих курсах Вы: \n \nСможете окунуться в мир белых и черных хакеров \n \nПолучите практические навыки взлома \n \nСможете попасть на стажировку в ведущие компании, связанные с информационной безопасностью \n \nСможете принять участие в соревнованиях CTF и выиграть много призов \n \nПознакомитесь с профессионалами в сфере информационной безопасности в различных крупных компаниях \n \nЕсли заинтересовался, приходи 18 сентября в 18:00 на Кирпичную 33 в 634 аудиторию, где ты сможешь послушать полную презентацию курса и задать любые вопросы.',
#      'attachments': [{'type': 'photo',
#        'photo': {'id': 456239028,
#         'album_id': -7,
#         'owner_id': -161949560,
#         'user_id': 100,
#         'photo_75': 'https://pp.userapi.com/c851536/v851536399/a18/bjJC40SaRGo.jpg',
#         'photo_130': 'https://pp.userapi.com/c851536/v851536399/a19/Np6X9PmV9wo.jpg',
#         'photo_604': 'https://pp.userapi.com/c851536/v851536399/a1a/5raXkb2wNgI.jpg',
#         'width': 560,
#         'height': 315,
#         'text': '',
#         'date': 1536747797,
#         'post_id': 26,
#         'access_key': '2e6c549289b589ab13'}}],
#      'post_source': {'type': 'vk'}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 10, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 1, 'user_reposted': 0},
#    'views': {'count': 5738}},
#   {'id': 32448,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1535952929,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': 'С началом нового учебного года коллектив университета поздравил Министр науки и высшего образования https://www.hse.ru/news/edu/222831157.html',
#    'attachments': [{'type': 'link',
#      'link': {'url': 'https://www.hse.ru/news/edu/222831157.html',
#       'title': 'Приветствие Министра науки и высшего образования РФ Михаила Котюкова студентам, руководству и препод',
#       'caption': 'hse.ru',
#       'description': 'Дорогие друзья! От имени Министерства науки и высшего образования Российской Федерации и лично от себя, поздравляю вас с началом нового учебного года!',
#       'photo': {'id': 456239087,
#        'album_id': -2,
#        'owner_id': 100,
#        'photo_75': 'https://pp.userapi.com/c845421/v845421881/dd7c8/V7QbOmr9EqE.jpg',
#        'photo_130': 'https://pp.userapi.com/c845421/v845421881/dd7c9/-92vE8SvDEQ.jpg',
#        'photo_604': 'https://pp.userapi.com/c845421/v845421881/dd7ca/90VIWDVYu4Q.jpg',
#        'width': 150,
#        'height': 100,
#        'text': '',
#        'date': 1535952929}}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 11, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 1, 'user_reposted': 0},
#    'views': {'count': 10101}},
#   {'id': 32447,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1535952608,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': 'В НИУ ВШЭ открывается новый факультет подготовки урбанистов https://www.hse.ru/news/edu/222771701.html',
#    'attachments': [{'type': 'link',
#      'link': {'url': 'https://www.hse.ru/news/edu/222771701.html',
#       'title': 'В Вышке открывается факультет городского и регионального развития',
#       'caption': 'www.hse.ru',
#       'description': 'Он должен вернуть в Россию профессию городского планировщика. О том, что будет сделано, рассказывает научный руководитель факультета, ординарный профессор ВШЭ Михаил Блинкин.',
#       'photo': {'id': 456240892,
#        'album_id': -2,
#        'owner_id': 100,
#        'photo_75': 'https://pp.userapi.com/c849336/v849336065/64092/w4Oxzi22-cc.jpg',
#        'photo_130': 'https://pp.userapi.com/c849336/v849336065/64093/PuZiOE_KBjI.jpg',
#        'photo_604': 'https://pp.userapi.com/c849336/v849336065/64094/j8DR6MQvvXk.jpg',
#        'width': 150,
#        'height': 101,
#        'text': '',
#        'date': 1535628987}}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 2, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 31, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'views': {'count': 9216}},
#   {'id': 32444,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1535657976,
#    'marked_as_ads': 0,
#    'post_type': 'post',
# ...
#          'photo_807': 'https://pp.userapi.com/c840428/v840428895/67316/mRTn7SbGVL8.jpg',
#          'photo_1280': 'https://pp.userapi.com/c840428/v840428895/67317/npgFkY_EwI0.jpg',
#          'photo_2560': 'https://pp.userapi.com/c840428/v840428895/67318/pOnHPS-pf8w.jpg',
#          'width': 2238,
#          'height': 1001,
#          'text': '',
#          'date': 1520960997}}}],
#      'post_source': {'type': 'vk'}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 3, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 1, 'user_reposted': 0},
#    'views': {'count': 6308}},
#   {'id': 32038,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1524137966,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': '',
#    'attachments': [{'type': 'link',
#      'link': {'url': 'https://events.webinar.ru/2972343/1014021',
#       'title': 'Маркетинг - Webinar',
#       'caption': 'events.webinar.ru',
#       'description': ''}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 1, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'views': {'count': 6492}},
#   {'id': 32037,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1524137943,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': 'Хочешь получить востребованную высокооплачиваемую специальность? Посети вебинар магистерской программы "Маркетинг", который пройдет 19 апреля в 18:30! Узнай подробности о поступлении, обучении и успехах выпускников от преподавателей и студентов программы. Регистрируйся и приходи! https://events.webinar.ru/2972343/1014021',
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 2, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 1, 'user_reposted': 0},
#    'views': {'count': 6259}},
#   {'id': 32036,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1523905424,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': '21 апреля состоится первый экологический бизнес-форум «Eco+номика: инновации в использовании ресурсов и новый стиль жизни» в НИУ ВШЭ! \n\nСтать участником просто – регистрируйтесь по ссылке: https://greenhse.timepad.ru/event/689540 \n\nВремя, проведенное на форуме, вы точно потратите не зря, потому что вас ждут: \n1. Гостевые лекции на тему проблем экологии в России и путей их решения от ИКЕА, KPMG, UPM, GreenPeace и других \n2. Круглый стол "Сжигать нельзя перерабатывать: как создать в России эффективный способ переработки отходов?" \n3. Игровой практикум "Используй разумно" и воркшоп по эко-брендингу \n4. Презентации лучших экологических практик стартапов и студенческих организаций \n5. Возможность попасть на стажировку в ведущие компании \n\nСледите за новостями в группе форума https://vk.com/economicaforum и участвуйте в конкурсе: https://vk.com/economicaforum?w=wall-163781621_11 \n\nДобавляйте в свой календарь: \n🌱21 апреля \n🌱Ул. Шаболовка, д. 26 \n🌱Приходить можно в любое время с 11 до 17:30. \n\nРегистрируйтесь по ссылке: https://greenhse.timepad.ru/event/689540 \nПриходите на форум Eco+номика!',
#    'attachments': [{'type': 'link',
#      'link': {'url': 'https://greenhse.timepad.ru/event/689540',
#       'title': 'Форум Eco+номика / События на TimePad.ru',
#       'caption': 'greenhse.timepad.ru',
#       'description': 'Eco+номика – это открытая дискуссионная площадка на базе НИУ ВШЭ, где крупные компании, представители органов власти, общественные организации встретятся со студентами и другими гостями форума для обсуждения наиболее острых экологических проблем в России, их решений, лучших «зеленых» практик и инноваций в использовании ресурсов.',
#       'photo': {'id': 456241636,
#        'album_id': -2,
#        'owner_id': 100,
#        'photo_75': 'https://sun1-5.userapi.com/c830608/v830608230/cd0e7/jg7oJDhTZrU.jpg',
#        'photo_130': 'https://sun1-20.userapi.com/c830608/v830608230/cd0e8/PoYQpHlNVMU.jpg',
#        'photo_604': 'https://sun1-19.userapi.com/c830608/v830608230/cd0ea/TVIdVxHhY6Y.jpg',
#        'width': 150,
#        'height': 150,
#        'text': '',
#        'date': 1523526582}}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 8, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 1, 'user_reposted': 0},
#    'views': {'count': 6461}},
#   {'id': 32035,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1523905292,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': 'Пользователь https://vk.com/eugene753 нашел стденческий билет Великой (МИРЭК, скорее всего). Найдите девушку, коллеги!',
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 1, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'views': {'count': 7446}},
#   {'id': 32034,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1523905024,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': 'Приглашаем на вебинар абитуриентов магистратуры https://www.hse.ru/webinar/announcements/215213845.html',
#    'attachments': [{'type': 'link',
#      'link': {'url': 'https://www.hse.ru/webinar/announcements/215213845.html',
#       'title': 'Вебинар магистерской программы «Экономика впечатлений: менеджмент в индустрии гостеприимства и туриз',
#       'caption': 'www.hse.ru',
#       'description': '16 мая в 18:00 состоится онлайн-презентация образовательной программы магистратуры факультета бизнеса и менеджмента Высшей школы экономики «Экономика впечатлений: менеджмент в индустрии гостеприимства и туризме». На вебинаре академический руководитель программы Предводителева Марина Дмитриевна ответит на все вопросы о поступлении и обучении на программе.',
#       'photo': {'id': 456240642,
#        'album_id': -2,
#        'owner_id': 100,
#        'photo_75': 'https://pp.userapi.com/c845421/v845421776/2ad02/c7f4UeG18J0.jpg',
#        'photo_130': 'https://pp.userapi.com/c845421/v845421776/2ad03/eSTfxKfVRnQ.jpg',
#        'photo_604': 'https://pp.userapi.com/c845421/v845421776/2ad05/MVXR60dJprg.jpg',
#        'width': 470,
#        'height': 246,
#        'text': '',
#        'date': 1523881512}}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 2, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 1, 'user_reposted': 0},
#    'views': {'count': 5968}},
#   {'id': 32033,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1523904989,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': 'Студенты факультета бизнеса и менеджмента организовали 1-Й Медунаодный хакатон под эгидой MLH. Первый 12-часовой хакатон успешно проведен в декабре. Теперь - международный формат, 36 часов невероятного напряжения сил, интеллекта, море драйва, интересные задания от ведущих компаний, крутые спикеры, призы от спонсоров! Регистрация https://bi.hse.ru/announcements/218106089.html',
#    'attachments': [{'type': 'link',
#      'link': {'url': 'https://bi.hse.ru/announcements/218106089.html',
#       'title': 'Hack.Moscow - первый международный 36-часовой хакатон под эгидой MLH в России',
#       'caption': 'bi.hse.ru',
#       'description': ''}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 3, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'views': {'count': 6451}},
#   {'id': 32032,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1523779453,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': '',
#    'copy_history': [{'id': 8309,
#      'owner_id': -35525659,
#      'from_id': -35525659,
#      'date': 1523554314,
#      'post_type': 'post',
#      'text': '⚡ Специально для "Высшей школы экономики"! Хотите построить карьеру в Правительстве Москвы? Приглашаем на мастер-класс Команды Мэра! 16 апреля министры и топ-руководители столицы встретятся со студентами НИУ ВШЭ и расскажут, как будет развиваться наш город в ближайшее время и как попасть на оплачиваемую Стажировку в Правительстве. Не пропустите! :) \n \n📍16 апреля, 15:30\nНИУ ВШЭ\nАуд. 311 \n\n🔝 Стажировка в Правительстве столицы - это лучший путь к началу карьеры на госслужбе :) 9 месяцев Вы будете работать лично под руководством первых лиц города, реализовывать собственные идеи и получать уникальный опыт городского управления. А по ее окончании сможете остаться на постоянную работу в органах власти. \n \n✍ Чтобы подать заявку, выбирайте интересное Вам направление Стажировки - "Экономика", "Правовое пространство", "Социальный город", "Медийный город" или "Комфортная городская среда", заполняйте анкету на mos.ru/talent и проходите конкурс. Будем рады видеть вас в Команде Мэра! \n \nЖдем вас на мастер-классе и на работе в Правительстве Москвы! Сделайте первый шаг навстречу своему будущему :) \n \n#стажерпм #хочувпм #командамэра #вшэ',
#      'attachments': [{'type': 'photo',
#        'photo': {'id': 456243011,
#         'album_id': -7,
#         'owner_id': -35525659,
#         'user_id': 100,
#         'photo_75': 'https://pp.userapi.com/c840731/v840731712/73256/gaxgX6qe_9k.jpg',
#         'photo_130': 'https://pp.userapi.com/c840731/v840731712/73257/TCx7S-3MjoI.jpg',
#         'photo_604': 'https://pp.userapi.com/c840731/v840731712/73258/_hACThPJWio.jpg',
#         'photo_807': 'https://pp.userapi.com/c840731/v840731712/73259/AJ9JlVuwD7A.jpg',
#         'photo_1280': 'https://pp.userapi.com/c840731/v840731712/7325a/xRbV1shAz0s.jpg',
#         'photo_2560': 'https://pp.userapi.com/c840731/v840731712/7325b/PrM8ldIXF2Y.jpg',
#         'width': 2480,
#         'height': 1754,
#         'text': '',
#         'date': 1523554314,
#         'post_id': 8309,
#         'access_key': '01ee55e63a4fa79b9b'}},
#       {'type': 'link',
#        'link': {'url': 'http://mos.ru/talent',
#         'title': 'Главная - Карьерный портал Правительства Москвы',
#         'description': '',
#         'target': 'internal'}}],
#      'post_source': {'type': 'vk'}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 2, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 1, 'user_reposted': 0},
#    'views': {'count': 5535}},
#   {'id': 32031,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1523696547,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': '',
#    'copy_history': [{'id': 3920,
#      'owner_id': -15290342,
#      'from_id': -15290342,
#      'date': 1523555676,
#      'post_type': 'post',
#      'text': 'Надоели бесконечные карьерные лекции о компаниях? Не хватает настоящей практики и опыта? \n\n18 апреля в НИУ ВШЭ пройдет бизнес-игра, приуроченная к проведению легендарного кейс-чемпионата по продажам [club112263708|Clash of Sales] от компании [club16417607|Unilever]❗ \nВ ходе бизнес-игры все участники смогут прокачать структурное мышление, необходимое для участия в кейс-чемпионатах, а также подтянуть навыки публичной защиты своего решения перед участием в них! \n\nВ 2018 году кейс-чемпионат [club112263708|Clash of Sales] впервые пройдет на стыке двух рынков – FMCG и Retail, а решения участников будут оценивать не только эксперты Unilever, но и представители «Перекрестка» – сети, входящей в состав холдинга Х5 Retail Group. Победителей чемпионата ждет ускоренный отбор на лидерские программы стажировок Unilever.\n\nМодератором игры выступит Илья Кельцев, выпускник НИУ ВШЭ и менеджер Unilever в отделе eCommerce Business Development. За время работы в Unilever Илья успел не только поработать в нескольких отделах компании и закончить программу UFLP, но и побывать на ротации в Лондоне! \n\nХочешь узнать, как? Мы ждем тебя:\n⏳18 апреля в 19:00 \n📍Шаболовка 26, аудитория 5306. \n\nВнимание❗  Требуется регистрация: http://case-club.ru/2-caseclub/517-unilever-4-18',
#      'attachments': [{'type': 'photo',
#        'photo': {'id': 456239593,
#         'album_id': -7,
#         'owner_id': -15290342,
#         'user_id': 100,
#         'photo_75': 'https://pp.userapi.com/c824701/v824701664/106cc4/vX3sHHXHN_I.jpg',
#         'photo_130': 'https://pp.userapi.com/c824701/v824701664/106cc5/faXHovz8aEs.jpg',
#         'photo_604': 'https://pp.userapi.com/c824701/v824701664/106cc6/iXrFI3fXBhA.jpg',
#         'photo_807': 'https://pp.userapi.com/c824701/v824701664/106cc7/62z-ty39wtc.jpg',
#         'photo_1280': 'https://pp.userapi.com/c824701/v824701664/106cc8/mo3MFCyYctg.jpg',
#         'photo_2560': 'https://pp.userapi.com/c824701/v824701664/106cc9/P5FhmRGaWTI.jpg',
#         'width': 1578,
#         'height': 1129,
#         'text': '',
#         'date': 1523555644,
#         'post_id': 3920,
#         'access_key': '64dcb0e94c74105203'}}],
#      'post_source': {'type': 'vk'}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 4, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'views': {'count': 5693}},
#   {'id': 32030,
#    'from_id': -132,
#    'owner_id': -132,
#    'date': 1523696439,
#    'marked_as_ads': 0,
#    'post_type': 'post',
#    'text': '',
#    'copy_history': [{'id': 935,
#      'owner_id': -85934227,
#      'from_id': -85934227,
#      'date': 1523355014,
#      'post_type': 'post',
#      'text': 'Что такое деньги для вас? Как вы привыкли их тратить? На «товары и услуги», как сказали бы на микре, правильно? \n \nНа следующем культурном кафе в рамках международного проекта ESN — Social Inclusion Days — мы расскажем вам об альтернативных способах использования денег, например, на добрые дела! 3 истории от трех студентов, которые, к удивлению для себя, стали фандрайзерами. \n \nЭто возможно/непросто/отнимает время, а вообще стоит того? Точно отвечаем: да. Торжественно клянёмся, что после Культурного кафе вы вдохновитесь на свой собственный благотворительный проект! \n\nА в течение мероприятия вы сможете пожертвовать деньги в поддержку интеграционного центра «Такие же дети» http://kidsarekids-center.com/ — центра, занимающегося обучением и адаптацией детей беженцев из Сирии, Конго, Афганистана, Украины и других стран.\n\nЖдём вас на Культурном кафе после короткой регистрации: esn-hse-moscow.timepad.ru/event/701408/ (с собой паспорт, если вы не из Вышки).\n \nЧТО: Culture Café: Добро и деньги \nКОГДА: 18 апреля, 18:30 \nГДЕ: Мясницкая, 11 ауд. 325 \nЗАЧЕМ: узнать о способах помогать окружающим в новой форме!\nРАБОЧИЙ ЯЗЫК: английский',
#      'attachments': [{'type': 'photo',
#        'photo': {'id': 456240006,
#         'album_id': -7,
#         'owner_id': -85934227,
#         'user_id': 100,
#         'photo_75': 'https://pp.userapi.com/c846121/v846121604/20040/i3cB8vR_AOY.jpg',
#         'photo_130': 'https://pp.userapi.com/c846121/v846121604/20041/kATYnpCmQdc.jpg',
#         'photo_604': 'https://pp.userapi.com/c846121/v846121604/20042/1V33tVCJoUk.jpg',
#         'photo_807': 'https://pp.userapi.com/c846121/v846121604/20043/vE1DqGeRjdo.jpg',
#         'photo_1280': 'https://pp.userapi.com/c846121/v846121604/20044/qX4bOSVHMk0.jpg',
#         'photo_2560': 'https://pp.userapi.com/c846121/v846121604/20045/7g-xXYNUXP0.jpg',
#         'width': 2160,
#         'height': 2160,
#         'text': '',
#         'date': 1523355014,
#         'post_id': 935,
#         'access_key': '95bcace928034541c9'}},
#       {'type': 'link',
#        'link': {'url': 'https://esn-hse-moscow.timepad.ru/event/701408/',
#         'title': 'Culture Café: money for Good / События на TimePad.ru',
#         'description': '',
#         'target': 'internal'}}],
#      'post_source': {'type': 'vk'}}],
#    'post_source': {'type': 'vk'},
#    'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#    'likes': {'count': 5, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'views': {'count': 5895}}]}

# %%
res_loaded['items'][:2]
# Out:
# [{'id': 32494,
#   'from_id': -132,
#   'owner_id': -132,
#   'date': 1541422799,
#   'marked_as_ads': 0,
#   'post_type': 'post',
#   'text': '',
#   'attachments': [{'type': 'link',
#     'link': {'url': 'http://family.hse.ru/event/view/2271',
#      'title': 'День карьеры факультета бизнеса и менеджмента',
#      'caption': 'family.hse.ru',
#      'description': '',
#      'photo': {'id': 456239093,
#       'album_id': -2,
#       'owner_id': 100,
#       'photo_75': 'https://pp.userapi.com/c850336/v850336548/628ea/TwPjzdADVZ4.jpg',
#       'photo_130': 'https://pp.userapi.com/c850336/v850336548/628eb/gMSUSljxiC8.jpg',
#       'photo_604': 'https://pp.userapi.com/c850336/v850336548/628ec/kIMEO_f_3JQ.jpg',
#       'width': 150,
#       'height': 80,
#       'text': '',
#       'date': 1541422799}}}],
#   'post_source': {'type': 'vk'},
#   'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#   'likes': {'count': 6, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#   'reposts': {'count': 2, 'user_reposted': 0},
#   'views': {'count': 2832}},
#  {'id': 32493,
#   'from_id': -132,
#   'owner_id': -132,
#   'date': 1541076555,
#   'marked_as_ads': 0,
#   'post_type': 'post',
#   'text': 'На Шаболовке 7 ноября в 18:30 ауд 5215 состоится встреча с представителем оргкомитета симпозиума, Lars John. Авторы лучших эссе получат возможность участвовать в симпозиуме в Швейцарии, а автор cамого лучшего эссе получит значительный денежный приз. Приглашаем всех студентов магистратуры, студентов 4 курса и аспирантов принять участие в этой встрече. \n \nTo all grad/postgrad and 4th year undergraduate students: compete until 1 Feb 2019 and qualify as a Leader of Tomorrow for the #49sgs (8–10 May 2019) in Switzerland, all expenses paid. Create an impact and win CHF 20,000. Leaders who have attended in the past include Niall Ferguson, Jack Ma, Christine Lagarde, Paul Polman, Anders Fogh Rasmussen, Ratan Tata, Muhammad Yunus, and many more. Register now at www.symp.sg/apply',
#   'post_source': {'type': 'vk'},
#   'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#   'likes': {'count': 2, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#   'reposts': {'count': 1, 'user_reposted': 0},
#   'views': {'count': 3943}}]

# %%
res_loaded.keys()
# Out:
# dict_keys(['count', 'items'])

# %% [markdown]
# Ключами являются `count` и `items`. Нужные нам объекты (текст постов, id автора, дата и время публикации и проч.) находятся в `items`.

# %%
res_loaded['items'][0] # первый элемент items - первый пост со всей информацией о нем
# Out:
# {'id': 32494,
#  'from_id': -132,
#  'owner_id': -132,
#  'date': 1541422799,
#  'marked_as_ads': 0,
#  'post_type': 'post',
#  'text': '',
#  'attachments': [{'type': 'link',
#    'link': {'url': 'http://family.hse.ru/event/view/2271',
#     'title': 'День карьеры факультета бизнеса и менеджмента',
#     'caption': 'family.hse.ru',
#     'description': '',
#     'photo': {'id': 456239093,
#      'album_id': -2,
#      'owner_id': 100,
#      'photo_75': 'https://pp.userapi.com/c850336/v850336548/628ea/TwPjzdADVZ4.jpg',
#      'photo_130': 'https://pp.userapi.com/c850336/v850336548/628eb/gMSUSljxiC8.jpg',
#      'photo_604': 'https://pp.userapi.com/c850336/v850336548/628ec/kIMEO_f_3JQ.jpg',
#      'width': 150,
#      'height': 80,
#      'text': '',
#      'date': 1541422799}}}],
#  'post_source': {'type': 'vk'},
#  'comments': {'count': 0, 'can_post': 1, 'groups_can_post': True},
#  'likes': {'count': 6, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#  'reposts': {'count': 2, 'user_reposted': 0},
#  'views': {'count': 2832}}

# %% [markdown]
# Помимо текста поста можно найти много всего интересного. Например, тип поста (`post_type`), дата (`date`), id поста (`id`), лайки (`likes`, которые включают информацию о том, могут ли пользователи лайкать пост и публиковать его, а также собственно число лайков), репосты (`reposts`, которые включают число репостов), число просмотров (`views`), комментарии (`comments`, которые включают информацию о том, могут ли пользователи комментировать пост, и число комментариев), и так далее.
#
# Давайте остановимся на тексте поста, id автора, id поста и дате публикации. Чтобы извлечь соответствующую информацию, сохраним `items` и извлечем из них нужные поля:

# %%
items = res_loaded['items']
full_list = []

for item in items:
    l = [item['from_id'], item['id'], item['text'], item['date']] # нужные поля
    full_list.append(l) # добавляем в список списков full_list
# несколько элементов списка
full_list[0:4]
# Out:
# [[-132, 32494, '', 1541422799],
#  [-132,
#   32493,
#   'На Шаболовке 7 ноября в 18:30 ауд 5215 состоится встреча с представителем оргкомитета симпозиума, Lars John. Авторы лучших эссе получат возможность участвовать в симпозиуме в Швейцарии, а автор cамого лучшего эссе получит значительный денежный приз. Приглашаем всех студентов магистратуры, студентов 4 курса и аспирантов принять участие в этой встрече. \n \nTo all grad/postgrad and 4th year undergraduate students: compete until 1 Feb 2019 and qualify as a Leader of Tomorrow for the #49sgs (8–10 May 2019) in Switzerland, all expenses paid. Create an impact and win CHF 20,000. Leaders who have attended in the past include Niall Ferguson, Jack Ma, Christine Lagarde, Paul Polman, Anders Fogh Rasmussen, Ratan Tata, Muhammad Yunus, and many more. Register now at www.symp.sg/apply',
#   1541076555],
#  [-132, 32492, '', 1540743239],
#  [-132, 32491, '', 1540551399]]

# %% [markdown]
# Видно, что в двух первых постах текста не обнаружено, там только картинки, ссылки и репосты.
#
# Из этого списка списков можно легко сделать датафрейм `pandas`.

# %% [markdown]
# Но если у ссылок, репостов и картинок нет текста, то наш DataFrame будет выглядет неполноценно. Поэтому добавим условие, что если текст отсутсвует, вставим в DataFrame строку с этой отметкой.

# %%
# опять выберем только нужные поля
full_list = []
for item in items:
    if item['text'] == "":
        l = [item['from_id'], item['id'], "Картинка, ссылка или репост", item['date']]
    else:
        l = [item['from_id'], item['id'], item['text'], item['date']]
    full_list.append(l)

# %% [markdown]
# Оставлось превратить обновленный список `items` (список списков) в датафрейм. Импортируем `pandas`.

# %%
import pandas as pd

# %% [markdown]
# Создадим датафрейм:

# %%
df = pd.DataFrame(full_list)
df.head(10)
# Out:
#      0      1                                                  2           3
# 0 -132  32494                        Картинка, ссылка или репост  1541422799
# 1 -132  32493  На Шаболовке 7 ноября в 18:30 ауд 5215 состоит...  1541076555
# 2 -132  32492                        Картинка, ссылка или репост  1540743239
# 3 -132  32491                        Картинка, ссылка или репост  1540551399
# 4 -132  32488                        Картинка, ссылка или репост  1540302306
# 5 -132  32486  26-28 октября в Москве пройдет крупнейший в Ро...  1539863523
# 6 -132  32485                        Картинка, ссылка или репост  1539781575
# 7 -132  32484                        Картинка, ссылка или репост  1539718883
# 8 -132  32481                        Картинка, ссылка или репост  1539088885
# 9 -132  32480  Будущим магистрам! Новая программа Факультета ...  1539088745

# %% [markdown]
# Ура! Осталось только дать внятные названия столбцам и разобраться, почему дата представлена в таком виде. что делать со столбцами, мы уже знаем.

# %%
df.columns = ['From_id', 'Id', 'Text', 'Date_Unix']
df.head(10)
# Out:
#    From_id     Id                                               Text  \
# 0     -132  32494                        Картинка, ссылка или репост
# 1     -132  32493  На Шаболовке 7 ноября в 18:30 ауд 5215 состоит...
# 2     -132  32492                        Картинка, ссылка или репост
# 3     -132  32491                        Картинка, ссылка или репост
# 4     -132  32488                        Картинка, ссылка или репост
# 5     -132  32486  26-28 октября в Москве пройдет крупнейший в Ро...
# 6     -132  32485                        Картинка, ссылка или репост
# 7     -132  32484                        Картинка, ссылка или репост
# 8     -132  32481                        Картинка, ссылка или репост
# 9     -132  32480  Будущим магистрам! Новая программа Факультета ...
#
#     Date_Unix
# 0  1541422799
# 1  1541076555
# 2  1540743239
# 3  1540551399
# 4  1540302306
# 5  1539863523
# 6  1539781575
# 7  1539718883
# 8  1539088885
# 9  1539088745

# %% [markdown]
# С датой все интереснее. То, что указано в столбце `date`, это дата в виде UNIX-времени (POSIX-времени). Это число секунд, прошедших с 1 января 1970 года. Несмотря на то, что такой формат даты-времени кажется необычным, он довольно широко распространен в разных системах и приложениях. Этот факт, конечно, радует, но хочется получить дату в более человеческом формате. Давайте напишем функцию для перевода UNIX-времени в формат год-месяц-день-часы-минуты-секунды. Для этого нам понадобится модуль datetime.

# %%
from datetime import datetime

# %%
def date_norm(date):
    d = datetime.fromtimestamp(date) # timestamp - UNIX-время в виде строки
    str_d = d.strftime("%Y-%m-%d %H:%M:%S") # %Y-%m-%d %H:%M:%S - год-месяц-день, часы:минуты:секунды
    date_norm, time_norm = str_d.split(' ') # разобьем результат на части, отделим дату от времени
    return date_norm, time_norm

# %% [markdown]
# Применим нашу функцию к элементам столбца date и создадим новый ‒ `date_norm`.

# %%
df['Date_Norm'] = df.Date_Unix.apply(date_norm)

# %%
df.head()
# Out:
#    From_id     Id                                               Text  \
# 0     -132  32494                        Картинка, ссылка или репост
# 1     -132  32493  На Шаболовке 7 ноября в 18:30 ауд 5215 состоит...
# 2     -132  32492                        Картинка, ссылка или репост
# 3     -132  32491                        Картинка, ссылка или репост
# 4     -132  32488                        Картинка, ссылка или репост
#
#     Date_Unix               Date_Norm
# 0  1541422799  (2018-11-05, 15:59:59)
# 1  1541076555  (2018-11-01, 15:49:15)
# 2  1540743239  (2018-10-28, 19:13:59)
# 3  1540551399  (2018-10-26, 13:56:39)
# 4  1540302306  (2018-10-23, 16:45:06)

# %% [markdown]
# Можно было, конечно, не разбивать на части дату и время, сохранять одной строкой. А можно написать функции, которые будут отделять дату от времени ‒ извлекать их из кортежа в date_norm.

# %%
def get_date(date):
    return date[0]

def get_time(date):
    return date[1]

# %%
df['Date'] = df.Date_Norm.apply(get_date)
df['Time'] = df.Date_Norm.apply(get_time)
df.head()
# Out:
#    From_id     Id                                               Text  \
# 0     -132  32494                        Картинка, ссылка или репост
# 1     -132  32493  На Шаболовке 7 ноября в 18:30 ауд 5215 состоит...
# 2     -132  32492                        Картинка, ссылка или репост
# 3     -132  32491                        Картинка, ссылка или репост
# 4     -132  32488                        Картинка, ссылка или репост
#
#     Date_Unix               Date_Norm        Date      Time
# 0  1541422799  (2018-11-05, 15:59:59)  2018-11-05  15:59:59
# 1  1541076555  (2018-11-01, 15:49:15)  2018-11-01  15:49:15
# 2  1540743239  (2018-10-28, 19:13:59)  2018-10-28  19:13:59
# 3  1540551399  (2018-10-26, 13:56:39)  2018-10-26  13:56:39
# 4  1540302306  (2018-10-23, 16:45:06)  2018-10-23  16:45:06

# %% [markdown]
# Всё! Материалы о разных методах и функциях для `vk.api` можно найти в [официальной документации](https://vk.com/dev/manuals).

# %% [markdown]
# ## Координаты МКС

# %% [markdown]
# Тут можно посмотреть положение МКС http://open-notify.org/Open-Notify-API/ISS-Location-Now/

# %% [markdown]
# Ссылка для получения json: http://api.open-notify.org/iss-now.json

# %%
import json
d = requests.get('http://api.open-notify.org/iss-now.json').json()

# %%
json.loads(requests.get('http://api.open-notify.org/iss-now.json').text)
# Out:
# {'message': 'success',
#  'timestamp': 1679138076,
#  'iss_position': {'latitude': '-2.2270', 'longitude': '71.7875'}}

# %%
d['iss_position']['longitude']
# Out:
# '114.9936'

# %%
from datetime import datetime

# %%
datetime.fromtimestamp(1679138076).strftime("%Y-%m-%d %H:%M:%S")
# Out:
# '2023-03-18 14:14:36'

# %%
def get_date(date):
    d = datetime.fromtimestamp(date) # timestamp - UNIX-время в виде строки
    str_d = d.strftime("%Y-%m-%d %H:%M:%S") # %Y-%m-%d %H:%M:%S - год-месяц-день, часы:минуты:секунды
    return str_d

# %%
get_date(1665229354)
# Out:
# '2022-10-08 14:42:34'

# %%
def get_iss_position():
    s = requests.get('http://api.open-notify.org/iss-now.json').json()
    return get_date(s['timestamp']), s['iss_position']['latitude'], s['iss_position']['longitude']

# %%
get_iss_position()
# Out:
# ('2023-03-18 14:20:24', '15.2795', '84.5740')

# %% [markdown]
# В какой стране находятся координаты:
# https://www.geonames.org/
#
# Тут нужно зарегистрироваться

# %%
def get_country(lat, long):
    url = 'http://api.geonames.org/countryCodeJSON'
    parameters = {
        'lat':lat,
        'lng':long,
        'username': 'pileyan'
    }
    return requests.get(url, parameters).json()
# ['countryName']

# %%
date, latitude, longitude = get_iss_position()
country = get_country(latitude, longitude)

# %%
country
# Out:
# {'languages': 'en-IN,hi,bn,te,mr,ta,ur,gu,kn,ml,or,pa,as,bh,sat,ks,ne,sd,kok,doi,mni,sit,sa,fr,lus,inc',
#  'distance': '0',
#  'countryCode': 'IN',
#  'countryName': 'India'}

# %%
def iss_monitor():
    date, latitude, longitude = get_iss_position()
    country = get_country(latitude, longitude)
    return {'date': date, 'latitude': latitude, 'longitude': longitude, 'country': country}

# %%
iss_monitor()
# Out:
# {'date': '2023-03-18 14:24:20',
#  'latitude': '26.6684',
#  'longitude': '94.5173',
#  'country': {'languages': 'en-IN,hi,bn,te,mr,ta,ur,gu,kn,ml,or,pa,as,bh,sat,ks,ne,sd,kok,doi,mni,sit,sa,fr,lus,inc',
#   'distance': '0',
#   'countryCode': 'IN',
#   'countryName': 'India'}}

# %%
import time

# %%
time.sleep(1)

# %%
lst = []
for i in range(75):
    lst.append(iss_monitor())
    time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-0c7b4ced6667> in <module>
#       2 for i in range(75):
#       3     lst.append(iss_monitor())
# ----> 4     time.sleep(5)
#
# KeyboardInterrupt:

# %%
lst
# Out:
# [{'date': '2023-03-18 14:24:28',
#   'latitude': '27.0173',
#   'longitude': '94.8644',
#   'country': {'languages': 'en-IN,hi,bn,te,mr,ta,ur,gu,kn,ml,or,pa,as,bh,sat,ks,ne,sd,kok,doi,mni,sit,sa,fr,lus,inc',
#    'distance': '0',
#    'countryCode': 'IN',
#    'countryName': 'India'}},
#  {'date': '2023-03-18 14:24:33',
#   'latitude': '27.2726',
#   'longitude': '95.1205',
#   'country': {'languages': 'en-IN,hi,bn,te,mr,ta,ur,gu,kn,ml,or,pa,as,bh,sat,ks,ne,sd,kok,doi,mni,sit,sa,fr,lus,inc',
#    'distance': '0',
#    'countryCode': 'IN',
#    'countryName': 'India'}},
#  {'date': '2023-03-18 14:24:39',
#   'latitude': '27.5273',
#   'longitude': '95.3778',
#   'country': {'languages': 'en-IN,hi,bn,te,mr,ta,ur,gu,kn,ml,or,pa,as,bh,sat,ks,ne,sd,kok,doi,mni,sit,sa,fr,lus,inc',
#    'distance': '0',
#    'countryCode': 'IN',
#    'countryName': 'India'}},
#  {'date': '2023-03-18 14:24:44',
#   'latitude': '27.7814',
#   'longitude': '95.6365',
#   'country': {'languages': 'en-IN,hi,bn,te,mr,ta,ur,gu,kn,ml,or,pa,as,bh,sat,ks,ne,sd,kok,doi,mni,sit,sa,fr,lus,inc',
#    'distance': '0',
#    'countryCode': 'IN',
#    'countryName': 'India'}},
#  {'date': '2023-03-18 14:24:50',
#   'latitude': '28.0349',
#   'longitude': '95.8963',
#   'country': {'languages': 'en-IN,hi,bn,te,mr,ta,ur,gu,kn,ml,or,pa,as,bh,sat,ks,ne,sd,kok,doi,mni,sit,sa,fr,lus,inc',
#    'distance': '0',
#    'countryCode': 'IN',
#    'countryName': 'India'}},
#  {'date': '2023-03-18 14:24:55',
#   'latitude': '28.2879',
#   'longitude': '96.1577',
#   'country': {'languages': 'en-IN,hi,bn,te,mr,ta,ur,gu,kn,ml,or,pa,as,bh,sat,ks,ne,sd,kok,doi,mni,sit,sa,fr,lus,inc',
#    'distance': '0',
#    'countryCode': 'IN',
#    'countryName': 'India'}},
#  {'date': '2023-03-18 14:25:00',
#   'latitude': '28.5174',
#   'longitude': '96.3964',
#   'country': {'status': {'message': 'no country code found', 'value': 15}}},
#  {'date': '2023-03-18 14:25:06',
#   'latitude': '28.7693',
#   'longitude': '96.6604',
#   'country': {'languages': 'zh-CN,yue,wuu,dta,ug,za',
#    'distance': '0',
#    'countryCode': 'CN',
#    'countryName': 'China'}},
#  {'date': '2023-03-18 14:25:11',
#   'latitude': '29.0206',
#   'longitude': '96.9257',
#   'country': {'languages': 'zh-CN,yue,wuu,dta,ug,za',
#    'distance': '0',
#    'countryCode': 'CN',
#    'countryName': 'China'}},
#  {'date': '2023-03-18 14:25:17',
#   'latitude': '29.2712',
#   'longitude': '97.1924',
#   'country': {'languages': 'zh-CN,yue,wuu,dta,ug,za',
#    'distance': '0',
#    'countryCode': 'CN',
#    'countryName': 'China'}},
#  {'date': '2023-03-18 14:25:22',
#   'latitude': '29.5212',
#   'longitude': '97.4606',
#   'country': {'status': {'message': 'no country code found', 'value': 15}}},
#  {'date': '2023-03-18 14:25:28',
#   'latitude': '29.7706',
#   'longitude': '97.7302',
#   'country': {'languages': 'zh-CN,yue,wuu,dta,ug,za',
#    'distance': '0',
#    'countryCode': 'CN',
#    'countryName': 'China'}},
#  {'date': '2023-03-18 14:25:34',
#   'latitude': '30.0193',
#   'longitude': '98.0013',
#   'country': {'languages': 'zh-CN,yue,wuu,dta,ug,za',
#    'distance': '0',
#    'countryCode': 'CN',
#    'countryName': 'China'}},
#  {'date': '2023-03-18 14:25:39',
#   'latitude': '30.2674',
#   'longitude': '98.2738',
#   'country': {'languages': 'zh-CN,yue,wuu,dta,ug,za',
#    'distance': '0',
#    'countryCode': 'CN',
#    'countryName': 'China'}},
#  {'date': '2023-03-18 14:25:45',
#   'latitude': '30.5148',
#   'longitude': '98.5478',
#   'country': {'languages': 'zh-CN,yue,wuu,dta,ug,za',
#    'distance': '0',
#    'countryCode': 'CN',
#    'countryName': 'China'}},
#  {'date': '2023-03-18 14:25:50',
#   'latitude': '30.7615',
#   'longitude': '98.8234',
#   'country': {'languages': 'zh-CN,yue,wuu,dta,ug,za',
#    'distance': '0',
#    'countryCode': 'CN',
#    'countryName': 'China'}},
#  {'date': '2023-03-18 14:25:56',
#   'latitude': '31.0075',
#   'longitude': '99.1005',
#   'country': {'languages': 'zh-CN,yue,wuu,dta,ug,za',
#    'distance': '0',
#    'countryCode': 'CN',
#    'countryName': 'China'}}]

# %%
import requests
from selenium import webdriver

driver = webdriver.Firefox()

# %%
driver.get('https://reverb.com/marketplace?query=paoletti%20%20nancy')

# %%
parsed = BeautifulSoup(driver.page_source)

# %%
import numpy as np

# %%
mean = np.mean([float(i.text[1:].replace(',','')) for i in parsed.find_all('span', {'class':'price-display'})])

# %%
USD_currency = requests.get('https://www.cbr-xml-daily.ru/daily_json.js').json()['Valute']['USD']['Value']

# %%
mean*USD_currency
# Out:
# 404102.1790376471
